# %% [markdown]
# # About this Notebook
# Here I am using Twitter twites to Extaction-Analysis and NLP Sentiment Analysis

# %% [markdown]
# # Importing Necesseties

# %%
import re
import string
import numpy as np 
import random
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from plotly import graph_objs as go
import plotly.express as px
import plotly.figure_factory as ff
from collections import Counter

from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator


import nltk
from nltk.corpus import stopwords

from tqdm import tqdm
import os
import nltk
import spacy
import random
from spacy.util import compounding
from spacy.util import minibatch

import warnings
warnings.filterwarnings("ignore")

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/tse-spacy-model/models/model_pos/tokenizer
# /kaggle/input/tse-spacy-model/models/model_pos/meta.json
# /kaggle/input/tse-spacy-model/models/model_pos/vocab/key2row
# /kaggle/input/tse-spacy-model/models/model_pos/vocab/vectors
# /kaggle/input/tse-spacy-model/models/model_pos/vocab/strings.json
# /kaggle/input/tse-spacy-model/models/model_pos/vocab/lexemes.bin
# /kaggle/input/tse-spacy-model/models/model_pos/ner/cfg
# /kaggle/input/tse-spacy-model/models/model_pos/ner/model
# /kaggle/input/tse-spacy-model/models/model_pos/ner/moves
# /kaggle/input/tse-spacy-model/models/model_neu/tokenizer
# /kaggle/input/tse-spacy-model/models/model_neu/meta.json
# /kaggle/input/tse-spacy-model/models/model_neu/vocab/key2row
# /kaggle/input/tse-spacy-model/models/model_neu/vocab/vectors
# /kaggle/input/tse-spacy-model/models/model_neu/vocab/strings.json
# /kaggle/input/tse-spacy-model/models/model_neu/vocab/lexemes.bin
# /kaggle/input/tse-spacy-model/models/model_neu/ner/cfg
# /kaggle/input/tse-spacy-model/models/model_neu/ner/model
# /kaggle/input/tse-spacy-model/models/model_neu/ner/moves
# /kaggle/input/tse-spacy-model/models/model_neg/tokenizer
# /kaggle/input/tse-spacy-model/models/model_neg/meta.json
# /kaggle/input/tse-spacy-model/models/model_neg/vocab/key2row
# /kaggle/input/tse-spacy-model/models/model_neg/vocab/vectors
# /kaggle/input/tse-spacy-model/models/model_neg/vocab/strings.json
# /kaggle/input/tse-spacy-model/models/model_neg/vocab/lexemes.bin
# /kaggle/input/tse-spacy-model/models/model_neg/ner/cfg
# /kaggle/input/tse-spacy-model/models/model_neg/ner/model
# /kaggle/input/tse-spacy-model/models/model_neg/ner/moves
# /kaggle/input/tse-spacy-model/models2/model_neg/tokenizer
# /kaggle/input/tse-spacy-model/models2/model_neg/meta.json
# /kaggle/input/tse-spacy-model/models2/model_neg/vocab/key2row
# /kaggle/input/tse-spacy-model/models2/model_neg/vocab/vectors
# /kaggle/input/tse-spacy-model/models2/model_neg/vocab/strings.json
# /kaggle/input/tse-spacy-model/models2/model_neg/vocab/lexemes.bin
# /kaggle/input/tse-spacy-model/models2/model_neg/ner/cfg
# /kaggle/input/tse-spacy-model/models2/model_neg/ner/model
# /kaggle/input/tse-spacy-model/models2/model_neg/ner/moves
# /kaggle/input/tweet-sentiment-extraction/sample_submission.csv
# /kaggle/input/tweet-sentiment-extraction/test.csv
# /kaggle/input/tweet-sentiment-extraction/train.csv

# %% [markdown]
# **Below is a helper Function which generates random colors which can be used to give different colors to your plots.Feel free to use it**

# %%
def random_colours(number_of_colors):
    '''
    Simple function for random colours generation.
    Input:
        number_of_colors - integer value indicating the number of colours which are going to be generated.
    Output:
        Color in the following format: ['#E86DA4'] .
    '''
    colors = []
    for i in range(number_of_colors):
        colors.append("#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)]))
    return colors

# %% [markdown]
# # Reading the Data

# %%
train = pd.read_csv('/kaggle/input/tweet-sentiment-extraction/train.csv')
test = pd.read_csv('/kaggle/input/tweet-sentiment-extraction/test.csv')
ss = pd.read_csv('/kaggle/input/tweet-sentiment-extraction/sample_submission.csv')

# %%
print(train.shape)
print(test.shape)
# Out:
# (27481, 4)
# (3534, 3)

# %% [markdown]
# So We have 27486 tweets in the train set and 3535 tweets in the test set

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27481 entries, 0 to 27480
# Data columns (total 4 columns):
# textID           27481 non-null object
# text             27480 non-null object
# selected_text    27480 non-null object
# sentiment        27481 non-null object
# dtypes: object(4)
# memory usage: 858.9+ KB

# %% [markdown]
# We have one null Value in the train , as the test field for value is NAN we will just remove it

# %%
train.dropna(inplace=True)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3534 entries, 0 to 3533
# Data columns (total 3 columns):
# textID       3534 non-null object
# text         3534 non-null object
# sentiment    3534 non-null object
# dtypes: object(3)
# memory usage: 83.0+ KB

# %% [markdown]
# There are no null Values in the test set

# %% [markdown]
# # EDA

# %%
train.head()
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative

# %% [markdown]
# Selected_text is a subset of text

# %%
train.describe()
# Out:
#             textID                                               text  \
# count        27480                                              27480
# unique       27480                                              27480
# top     820116989a  Spanish... The suckiest class ever. But I`m le...
# freq             1                                                  1
#
#        selected_text sentiment
# count          27480     27480
# unique         22463         3
# top             good   neutral
# freq             199     11117

# %% [markdown]
# Lets look at the distribution of tweets in the train set

# %%
temp = train.groupby('sentiment').count()['text'].reset_index().sort_values(by='text',ascending=False)
temp.style.background_gradient(cmap='Purples')
# Out:
# <style  type="text/css" >
#     #T_bd692bfa_a292_11ea_b7a8_351e50286832row0_col1 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_bd692bfa_a292_11ea_b7a8_351e50286832row1_col1 {
#             background-color:  #dcdcec;
#             color:  #000000;
#         }    #T_bd692bfa_a292_11ea_b7a8_351e50286832row2_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }</style><table id="T_bd692bfa_a292_11ea_b7a8_351e50286832" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sentiment</th>        <th class="col_heading level0 col1" >text</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bd692bfa_a292_11ea_b7a8_351e50286832level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_bd692bfa_a292_11ea_b7a8_351e50286832row0_col0" class="data row0 col0" >neutral</td>
#                         <td id="T_bd692bfa_a292_11ea_b7a8_351e50286832row0_col1" class="data row0 col1" >11117</td>
#             </tr>
#             <tr>
#                         <th id="T_bd692bfa_a292_11ea_b7a8_351e50286832level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_bd692bfa_a292_11ea_b7a8_351e50286832row1_col0" class="data row1 col0" >positive</td>
#                         <td id="T_bd692bfa_a292_11ea_b7a8_351e50286832row1_col1" class="data row1 col1" >8582</td>
#             </tr>
#             <tr>
#                         <th id="T_bd692bfa_a292_11ea_b7a8_351e50286832level0_row2" class="row_heading level0 row2" >0</th>
#                         <td id="T_bd692bfa_a292_11ea_b7a8_351e50286832row2_col0" class="data row2 col0" >negative</td>
#                         <td id="T_bd692bfa_a292_11ea_b7a8_351e50286832row2_col1" class="data row2 col1" >7781</td>
#             </tr>
#     </tbody></table>

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='sentiment',data=train)

# %% [markdown]
# Let's draw a Funnel-Chart for better visualization

# %%
fig = go.Figure(go.Funnelarea(
    text =temp.sentiment,
    values = temp.text,
    title = {"position": "top center", "text": "Funnel-Chart of Sentiment Distribution"}
    ))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="570a3313-3b3e-4bd4-97a9-dc9f8054f0e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("570a3313-3b3e-4bd4-97a9-dc9f8054f0e9")) {
#                     Plotly.newPlot(
#                         '570a3313-3b3e-4bd4-97a9-dc9f8054f0e9',
#                         [{"text": ["neutral", "positive", "negative"], "title": {"position": "top center", "text": "Funnel-Chart of Sentiment Distribution"}, "type": "funnelarea", "values": [11117, 8582, 7781]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %% [markdown]
# ## What do we currently Know About our Data:
#
# Before starting let's look at some things that we already know about the data and will help us in gaining more new insights:
# * We Know that selected_text is a subset of text
# * We know that selected_text contains only one segment of text,i.e,It does not jump between two sentences.For Eg:- If text is 'Spent the entire morning in a meeting w/ a vendor, and my boss was not happy w/ them. Lots of fun.  I had other plans for my morning' The selected text can be 'my boss was not happy w/ them. Lots of fun' or 'Lots of fun' but cannot be 'Morning,vendor and my boss,
# * Thanks to this discussion:https://www.kaggle.com/c/tweet-sentiment-extraction/discussion/138520 We know that neutral tweets have a jaccard similarity of 97 percent between text and selected_text
# * Also as discussed here https://www.kaggle.com/c/tweet-sentiment-extraction/discussion/138272 ,there are rows where selected_text starts from between the words and thus selected_texts dont always make sense and since we do not know whether the output of test set contain these descrepancies or not ,we are not sure that preprocessing and removing punctuations would be a good idea or not

# %% [markdown]
# ## Generating Meta-Features

# %% [markdown]
# **In the previous versions of this notebook,I used Number of words in selected text and main text ,Length of words in text and selected as main meta features,but in the context of this competition where we have to predict selected_text which is a subset of text, more useful features to generate would be** :-
# * Difference In Number Of words of Selected_text and Text
# * Jaccard Similarity Scores between text and Selected_text
#
# Thus it will not be useful for us to generate features we used before as they are of no importance here
#
# For what who don't know what Jaccard Similarity is : https://www.geeksforgeeks.org/find-the-jaccard-index-and-jaccard-distance-between-the-two-given-sets/

# %%
def jaccard(str1, str2): 
    a = set(str1.lower().split()) 
    b = set(str2.lower().split())
    c = a.intersection(b)
    return float(len(c)) / (len(a) + len(b) - len(c))

# %%
results_jaccard=[]

for ind,row in train.iterrows():
    sentence1 = row.text
    sentence2 = row.selected_text

    jaccard_score = jaccard(sentence1,sentence2)
    results_jaccard.append([sentence1,sentence2,jaccard_score])

# %%
jaccard = pd.DataFrame(results_jaccard,columns=["text","selected_text","jaccard_score"])
train = train.merge(jaccard,how='outer')

# %%
train['Num_words_ST'] = train['selected_text'].apply(lambda x:len(str(x).split())) #Number Of words in Selected Text
train['Num_word_text'] = train['text'].apply(lambda x:len(str(x).split())) #Number Of words in main text
train['difference_in_words'] = train['Num_word_text'] - train['Num_words_ST'] #Difference in Number of words text and Selected Text

# %%
train.head()
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment  jaccard_score  Num_words_ST  \
# 0  I`d have responded, if I were going   neutral       1.000000             7
# 1                             Sooo SAD  negative       0.200000             2
# 2                          bullying me  negative       0.166667             2
# 3                       leave me alone  negative       0.600000             3
# 4                        Sons of ****,  negative       0.214286             3
#
#    Num_word_text  difference_in_words
# 0              7                    0
# 1             10                    8
# 2              5                    3
# 3              5                    2
# 4             14                   11

# %% [markdown]
# Let's look at the distribution of Meta-Features

# %%
hist_data = [train['Num_words_ST'],train['Num_word_text']]

group_labels = ['Selected_Text', 'Text']

# Create distplot with custom bin_size
fig = ff.create_distplot(hist_data, group_labels,show_curve=False)
fig.update_layout(title_text='Distribution of Number Of words')
fig.update_layout(
    autosize=False,
    width=900,
    height=700,
    paper_bgcolor="LightSteelBlue",
)
fig.show()
# Out:
# <div>
#
#
#             <div id="4253aee0-337d-4725-b10f-3ae184af7c56" class="plotly-graph-div" style="height:700px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4253aee0-337d-4725-b10f-3ae184af7c56")) {
#                     Plotly.newPlot(
#                         '4253aee0-337d-4725-b10f-3ae184af7c56',
#                         [{"autobinx": false, "histnorm": "probability density", "legendgroup": "Selected_Text", "marker": {"color": "rgb(31, 119, 180)"}, "name": "Selected_Text", "opacity": 0.7, "type": "histogram", "x": [7, 2, 2, 3, 3, 12, 1, 2, 3, 5, 23, 1, 1, 1, 6, 5, 1, 1, 1, 6, 13, 1, 12, 18, 13, 11, 2, 2, 1, 6, 1, 1, 10, 1, 20, 8, 1, 24, 2, 4, 20, 3, 1, 25, 3, 18, 1, 5, 3, 8, 14, 10, 6, 10, 4, 11, 1, 4, 4, 6, 9, 2, 5, 1, 1, 4, 2, 16, 1, 9, 6, 1, 25, 18, 27, 27, 1, 4, 4, 12, 2, 1, 6, 1, 3, 10, 27, 28, 4, 1, 3, 9, 9, 1, 9, 9, 1, 1, 12, 1, 1, 5, 1, 1, 1, 11, 12, 1, 1, 7, 15, 2, 2, 25, 3, 4, 1, 4, 1, 24, 13, 25, 3, 2, 2, 3, 13, 1, 4, 2, 1, 4, 1, 1, 2, 2, 20, 21, 5, 5, 31, 1, 1, 3, 2, 17, 6, 9, 1, 1, 22, 3, 1, 1, 6, 6, 2, 22, 9, 11, 2, 6, 7, 1, 5, 1, 4, 16, 1, 1, 2, 5, 1, 23, 12, 5, 1, 7, 1, 20, 9, 4, 13, 1, 10, 2, 2, 1, 18, 1, 4, 2, 14, 11, 5, 4, 1, 2, 19, 15, 3, 1, 7, 3, 21, 1, 1, 7, 4, 5, 3, 7, 1, 1, 13, 4, 18, 2, 2, 20, 6, 3, 22, 6, 1, 5, 10, 1, 6, 2, 10, 5, 1, 6, 19, 11, 1, 7, 1, 1, 7, 27, 14, 7, 13, 1, 21, 6, 1, 7, 8, 14, 1, 23, 4, 12, 5, 1, 14, 15, 2, 4, 11, 21, 23, 3, 1, 4, 24, 2, 16, 2, 10, 1, 2, 1, 1, 1, 1, 4, 3, 1, 1, 11, 1, 5, 1, 6, 28, 5, 1, 8, 1, 21, 5, 3, 2, 3, 19, 9, 8, 14, 3, 29, 1, 1, 4, 21, 7, 2, 1, 3, 2, 1, 24, 17, 4, 1, 17, 1, 5, 26, 2, 27, 10, 3, 3, 1, 1, 6, 5, 3, 27, 5, 2, 12, 1, 2, 1, 3, 28, 1, 7, 3, 8, 1, 4, 5, 2, 1, 1, 9, 1, 1, 5, 4, 6, 4, 3, 7, 10, 2, 4, 6, 3, 15, 1, 28, 2, 23, 4, 5, 1, 2, 19, 4, 13, 3, 1, 12, 3, 8, 1, 15, 7, 10, 8, 1, 4, 2, 1, 22, 4, 10, 21, 8, 1, 1, 1, 2, 15, 3, 2, 21, 17, 4, 3, 3, 4, 18, 9, 1, 4, 1, 2, 5, 1, 11, 10, 8, 4, 4, 27, 1, 7, 2, 9, 1, 2, 1, 5, 20, 16, 1, 3, 15, 3, 1, 4, 21, 21, 12, 8, 2, 6, 6, 20, 7, 1, 8, 9, 1, 1, 2, 8, 1, 2, 5, 2, 22, 22, 9, 2, 4, 6, 4, 6, 2, 4, 4, 3, 2, 1, 1, 1, 22, 1, 20, 15, 6, 1, 5, 1, 1, 4, 12, 12, 1, 3, 1, 1, 1, 5, 3, 3, 7, 1, 4, 7, 1, 16, 11, 7, 5, 1, 4, 9, 1, 6, 11, 1, 10, 1, 1, 25, 15, 5, 1, 2, 1, 2, 1, 7, 22, 7, 8, 5, 10, 5, 4, 9, 1, 2, 1, 3, 27, 4, 22, 15, 2, 2, 12, 2, 1, 2, 7, 16, 1, 11, 12, 17, 3, 1, 9, 1, 6, 18, 1, 19, 10, 1, 15, 4, 4, 3, 17, 9, 9, 11, 9, 6, 3, 1, 1, 18, 2, 25, 5, 1, 15, 20, 1, 1, 6, 1, 13, 12, 1, 1, 1, 1, 6, 12, 1, 10, 6, 25, 3, 4, 1, 3, 13, 2, 6, 1, 3, 2, 1, 6, 1, 9, 2, 1, 29, 8, 5, 8, 1, 4, 23, 1, 2, 1, 6, 4, 1, 16, 11, 27, 6, 4, 1, 17, 7, 18, 1, 9, 3, 9, 1, 1, 3, 5, 12, 12, 1, 2, 9, 16, 7, 2, 1, 1, 1, 1, 8, 8, 9, 1, 1, 2, 10, 5, 4, 2, 1, 14, 1, 4, 1, 10, 1, 12, 5, 16, 4, 3, 5, 1, 1, 16, 22, 10, 4, 11, 6, 3, 2, 1, 8, 7, 1, 1, 25, 4, 6, 6, 1, 1, 24, 13, 2, 4, 1, 17, 27, 8, 3, 3, 1, 22, 13, 3, 1, 4, 1, 1, 1, 6, 1, 1, 8, 1, 1, 1, 9, 2, 6, 1, 27, 8, 1, 5, 2, 1, 1, 7, 14, 19, 12, 17, 1, 1, 8, 1, 16, 1, 3, 18, 3, 2, 2, 18, 19, 5, 6, 2, 1, 1, 8, 9, 14, 10, 11, 4, 1, 6, 3, 9, 1, 1, 19, 2, 28, 5, 4, 14, 1, 19, 1, 23, 1, 3, 25, 11, 1, 16, 15, 17, 5, 8, 18, 15, 1, 1, 1, 1, 2, 12, 17, 7, 1, 6, 2, 9, 12, 4, 5, 2, 20, 2, 2, 5, 1, 1, 1, 2, 23, 9, 1, 2, 1, 2, 5, 17, 6, 1, 3, 1, 14, 1, 15, 16, 2, 5, 12, 7, 11, 5, 1, 1, 1, 1, 7, 22, 13, 17, 26, 5, 16, 17, 3, 5, 4, 18, 2, 8, 19, 7, 19, 8, 2, 2, 4, 15, 6, 5, 5, 5, 3, 3, 1, 1, 5, 1, 2, 17, 3, 1, 5, 4, 1, 14, 2, 19, 23, 3, 27, 1, 3, 1, 4, 25, 2, 12, 16, 1, 1, 13, 5, 1, 1, 19, 1, 5, 2, 5, 4, 7, 28, 1, 4, 2, 3, 23, 1, 1, 6, 1, 18, 3, 18, 15, 1, 2, 1, 10, 1, 11, 1, 2, 11, 6, 5, 1, 15, 4, 18, 3, 23, 26, 2, 1, 14, 5, 1, 5, 9, 11, 2, 1, 19, 1, 1, 16, 2, 6, 4, 20, 1, 23, 1, 5, 6, 13, 5, 4, 10, 21, 1, 19, 1, 1, 2, 6, 2, 1, 1, 1, 11, 6, 14, 2, 11, 3, 17, 10, 1, 1, 1, 7, 4, 2, 12, 2, 5, 4, 10, 6, 5, 1, 1, 1, 1, 9, 9, 2, 2, 6, 2, 12, 5, 12, 2, 2, 24, 8, 19, 2, 4, 2, 16, 14, 4, 13, 1, 1, 4, 1, 9, 1, 13, 1, 14, 1, 4, 12, 6, 6, 6, 2, 1, 15, 1, 9, 5, 4, 10, 16, 24, 29, 26, 15, 1, 4, 7, 2, 7, 1, 16, 3, 2, 1, 6, 1, 15, 1, 4, 2, 3, 1, 20, 15, 7, 1, 6, 4, 22, 1, 2, 22, 3, 4, 13, 1, 1, 19, 1, 7, 1, 12, 20, 1, 1, 14, 4, 4, 11, 1, 3, 1, 16, 1, 10, 2, 4, 6, 1, 1, 1, 6, 9, 4, 1, 1, 6, 6, 2, 9, 16, 3, 2, 3, 1, 5, 19, 17, 18, 3, 13, 1, 9, 15, 3, 3, 1, 14, 1, 3, 1, 1, 13, 18, 22, 1, 1, 13, 19, 1, 2, 17, 10, 3, 11, 2, ...

# %% [markdown]
# * The number of words plot is really interesting ,the tweets having number of words greater than 25 are very less and thus the number of words distribution plot is right skewed

# %%
plt.figure(figsize=(12,6))
p1=sns.kdeplot(train['Num_words_ST'], shade=True, color="r").set_title('Kernel Distribution of Number Of words')
p1=sns.kdeplot(train['Num_word_text'], shade=True, color="b")

# %% [markdown]
# **Now It will be more interesting to see the differnce in number of words and jaccard_scores across different Sentiments**

# %%
plt.figure(figsize=(12,6))
p1=sns.kdeplot(train[train['sentiment']=='positive']['difference_in_words'], shade=True, color="b").set_title('Kernel Distribution of Difference in Number Of words')
p2=sns.kdeplot(train[train['sentiment']=='negative']['difference_in_words'], shade=True, color="r")

# %%
plt.figure(figsize=(12,6))
sns.distplot(train[train['sentiment']=='neutral']['difference_in_words'],kde=False)

# %% [markdown]
# I was not able to plot kde plot for neutral tweets because most of the values for difference in number of words were zero. We can see it clearly now ,if we had used the feature in the starting we would have known that text and selected text are mostly the same for neutral tweets,thus its always important to keep the end goal in mind while performing EDA

# %%
plt.figure(figsize=(12,6))
p1=sns.kdeplot(train[train['sentiment']=='positive']['jaccard_score'], shade=True, color="b").set_title('KDE of Jaccard Scores across different Sentiments')
p2=sns.kdeplot(train[train['sentiment']=='negative']['jaccard_score'], shade=True, color="r")
plt.legend(labels=['positive','negative'])

# %% [markdown]
# I was not able to plot kde of jaccard_scores of neutral tweets for the same reason,thus I will plot a distribution plot

# %%
plt.figure(figsize=(12,6))
sns.distplot(train[train['sentiment']=='neutral']['jaccard_score'],kde=False)

# %% [markdown]
# We can see some interesting trends here:
# * Positive and negative tweets have high kurtosis and thus values are concentrated in two regions narrow and high density
# * Neutral tweets have a low kurtosis value and their is bump in density near values of 1
#
# For those who don't know :
# * Kurtosis is the measure of how peaked a distribution is and how much spread it is around that peak
# * Skewness measures how much a curve deviates from a normal distribution

# %% [markdown]
# ## Conclusion Of EDA
#
# * We can see from the jaccard score plot that there is peak for negative and positive plot around score of 1 .That means there is a cluster of tweets where there is a high similarity between text and selected texts ,if we can find those clusters then we can predict text for selected texts for those tweets irrespective of segment
#
# Let's see if we can find those clusters,one interesting idea would be to check tweets which have number of words lesss than 3 in text, because there the text might be completely used as text

# %%
k = train[train['Num_word_text']<=2]

# %%
k.groupby('sentiment').mean()['jaccard_score']
# Out:
# sentiment
# negative    0.788580
# neutral     0.977805
# positive    0.765700
# Name: jaccard_score, dtype: float64

# %% [markdown]
# We can see that there is similarity between text and selected text .Let's have closer look

# %%
k[k['sentiment']=='positive']
# Out:
#            textID                              text  \
# 68     fa2654e730                          Chilliin
# 80     bbbc46889b   THANK YYYYYYYYYOOOOOOOOOOUUUUU!
# 170    f3d95b57b1                      good morning
# 278    89d5b3f0b5                            Thanks
# 429    a78ef3e0d0                       Goodmorning
# ...           ...                               ...
# 26689  e80c242d6a                        Goodnight;
# 26725  aad244f37d                             *hug*
# 26842  a46571fe12                         congrats!
# 26959  49a942e9b1                   Happy birthday.
# 27292  47c474aaf1                       Good choice
#
#                          selected_text sentiment  jaccard_score  Num_words_ST  \
# 68                            Chilliin  positive            1.0             1
# 80     THANK YYYYYYYYYOOOOOOOOOOUUUUU!  positive            1.0             2
# 170                       good morning  positive            1.0             2
# 278                             Thanks  positive            1.0             1
# 429                        Goodmorning  positive            1.0             1
# ...                                ...       ...            ...           ...
# 26689                       Goodnight;  positive            1.0             1
# 26725                            *hug*  positive            1.0             1
# 26842                        congrats!  positive            1.0             1
# 26959                  Happy birthday.  positive            1.0             2
# 27292                             Good  positive            0.5             1
#
#        Num_word_text  difference_in_words
# 68                 1                    0
# 80                 2                    0
# 170                2                    0
# 278                1                    0
# 429                1                    0
# ...              ...                  ...
# 26689              1                    0
# 26725              1                    0
# 26842              1                    0
# 26959              2                    0
# 27292              2                    1
#
# [207 rows x 8 columns]

# %% [markdown]
# Thus its clear that most of the times , text is used as selected text.We can improve this by preprocessing the text which have word length less than 3.We will remember this information and use it in model building

# %% [markdown]
# ### Cleaning the Corpus
# Now Before We Dive into extracting information out of words in text and selected text,let's first clean the data

# %%
def clean_text(text):
    '''Make text lowercase, remove text in square brackets,remove links,remove punctuation
    and remove words containing numbers.'''
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

# %%
train['text'] = train['text'].apply(lambda x:clean_text(x))
train['selected_text'] = train['selected_text'].apply(lambda x:clean_text(x))

# %%
train.head()
# Out:
#        textID                                               text  \
# 0  cb774db0d1                  id have responded if i were going
# 1  549e992a42         sooo sad i will miss you here in san diego
# 2  088c60f138                             my boss is bullying me
# 3  9642c003ef                      what interview leave me alone
# 4  358bd9e861   sons of  why couldnt they put them on the rel...
#
#                        selected_text sentiment  jaccard_score  Num_words_ST  \
# 0  id have responded if i were going   neutral       1.000000             7
# 1                           sooo sad  negative       0.200000             2
# 2                        bullying me  negative       0.166667             2
# 3                     leave me alone  negative       0.600000             3
# 4                           sons of   negative       0.214286             3
#
#    Num_word_text  difference_in_words
# 0              7                    0
# 1             10                    8
# 2              5                    3
# 3              5                    2
# 4             14                   11

# %% [markdown]
# ## Most Common words in our Target-Selected Text

# %%
train['temp_list'] = train['selected_text'].apply(lambda x:str(x).split())
top = Counter([item for sublist in train['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
#     #T_c57e9d98_a292_11ea_b7a8_351e50286832row0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_c57e9d98_a292_11ea_b7a8_351e50286832row1_col1 {
#             background-color:  #3383be;
#             color:  #000000;
#         }    #T_c57e9d98_a292_11ea_b7a8_351e50286832row2_col1 {
#             background-color:  #57a0ce;
#             color:  #000000;
#         }    #T_c57e9d98_a292_11ea_b7a8_351e50286832row3_col1 {
#             background-color:  #9ac8e0;
#             color:  #000000;
#         }    #T_c57e9d98_a292_11ea_b7a8_351e50286832row4_col1 {
#             background-color:  #c4daee;
#             color:  #000000;
#         }    #T_c57e9d98_a292_11ea_b7a8_351e50286832row5_col1 {
#             background-color:  #caddf0;
#             color:  #000000;
#         }    #T_c57e9d98_a292_11ea_b7a8_351e50286832row6_col1 {
#             background-color:  #d3e4f3;
#             color:  #000000;
#         }    #T_c57e9d98_a292_11ea_b7a8_351e50286832row7_col1 {
#             background-color:  #d9e7f5;
#             color:  #000000;
#         }    #T_c57e9d98_a292_11ea_b7a8_351e50286832row8_col1 {
#             background-color:  #dae8f6;
#             color:  #000000;
#         }    #T_c57e9d98_a292_11ea_b7a8_351e50286832row9_col1 {
#             background-color:  #dfebf7;
#             color:  #000000;
#         }    #T_c57e9d98_a292_11ea_b7a8_351e50286832row10_col1 {
#             background-color:  #e3eef9;
#             color:  #000000;
#         }    #T_c57e9d98_a292_11ea_b7a8_351e50286832row11_col1 {
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }    #T_c57e9d98_a292_11ea_b7a8_351e50286832row12_col1 {
#             background-color:  #eaf3fb;
#             color:  #000000;
#         }    #T_c57e9d98_a292_11ea_b7a8_351e50286832row13_col1 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_c57e9d98_a292_11ea_b7a8_351e50286832row14_col1 {
#             background-color:  #eff6fc;
#             color:  #000000;
#         }    #T_c57e9d98_a292_11ea_b7a8_351e50286832row15_col1 {
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }    #T_c57e9d98_a292_11ea_b7a8_351e50286832row16_col1 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_c57e9d98_a292_11ea_b7a8_351e50286832row17_col1 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_c57e9d98_a292_11ea_b7a8_351e50286832row18_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_c57e9d98_a292_11ea_b7a8_351e50286832row19_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }</style><table id="T_c57e9d98_a292_11ea_b7a8_351e50286832" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Common_words</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c57e9d98_a292_11ea_b7a8_351e50286832level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c57e9d98_a292_11ea_b7a8_351e50286832row0_col0" class="data row0 col0" >i</td>
#                         <td id="T_c57e9d98_a292_11ea_b7a8_351e50286832row0_col1" class="data row0 col1" >7200</td>
#             </tr>
#             <tr>
#                         <th id="T_c57e9d98_a292_11ea_b7a8_351e50286832level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c57e9d98_a292_11ea_b7a8_351e50286832row1_col0" class="data row1 col0" >to</td>
#                         <td id="T_c57e9d98_a292_11ea_b7a8_351e50286832row1_col1" class="data row1 col1" >5305</td>
#             </tr>
#             <tr>
#                         <th id="T_c57e9d98_a292_11ea_b7a8_351e50286832level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c57e9d98_a292_11ea_b7a8_351e50286832row2_col0" class="data row2 col0" >the</td>
#                         <td id="T_c57e9d98_a292_11ea_b7a8_351e50286832row2_col1" class="data row2 col1" >4590</td>
#             </tr>
#             <tr>
#                         <th id="T_c57e9d98_a292_11ea_b7a8_351e50286832level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_c57e9d98_a292_11ea_b7a8_351e50286832row3_col0" class="data row3 col0" >a</td>
#                         <td id="T_c57e9d98_a292_11ea_b7a8_351e50286832row3_col1" class="data row3 col1" >3538</td>
#             </tr>
#             <tr>
#                         <th id="T_c57e9d98_a292_11ea_b7a8_351e50286832level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_c57e9d98_a292_11ea_b7a8_351e50286832row4_col0" class="data row4 col0" >my</td>
#                         <td id="T_c57e9d98_a292_11ea_b7a8_351e50286832row4_col1" class="data row4 col1" >2783</td>
#             </tr>
#             <tr>
#                         <th id="T_c57e9d98_a292_11ea_b7a8_351e50286832level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_c57e9d98_a292_11ea_b7a8_351e50286832row5_col0" class="data row5 col0" >you</td>
#                         <td id="T_c57e9d98_a292_11ea_b7a8_351e50286832row5_col1" class="data row5 col1" >2624</td>
#             </tr>
#             <tr>
#                         <th id="T_c57e9d98_a292_11ea_b7a8_351e50286832level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_c57e9d98_a292_11ea_b7a8_351e50286832row6_col0" class="data row6 col0" >and</td>
#                         <td id="T_c57e9d98_a292_11ea_b7a8_351e50286832row6_col1" class="data row6 col1" >2321</td>
#             </tr>
#             <tr>
#                         <th id="T_c57e9d98_a292_11ea_b7a8_351e50286832level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_c57e9d98_a292_11ea_b7a8_351e50286832row7_col0" class="data row7 col0" >it</td>
#                         <td id="T_c57e9d98_a292_11ea_b7a8_351e50286832row7_col1" class="data row7 col1" >2158</td>
#             </tr>
#             <tr>
#                         <th id="T_c57e9d98_a292_11ea_b7a8_351e50286832level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_c57e9d98_a292_11ea_b7a8_351e50286832row8_col0" class="data row8 col0" >is</td>
#                         <td id="T_c57e9d98_a292_11ea_b7a8_351e50286832row8_col1" class="data row8 col1" >2115</td>
#             </tr>
#             <tr>
#                         <th id="T_c57e9d98_a292_11ea_b7a8_351e50286832level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_c57e9d98_a292_11ea_b7a8_351e50286832row9_col0" class="data row9 col0" >in</td>
#                         <td id="T_c57e9d98_a292_11ea_b7a8_351e50286832row9_col1" class="data row9 col1" >1986</td>
#             </tr>
#             <tr>
#                         <th id="T_c57e9d98_a292_11ea_b7a8_351e50286832level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_c57e9d98_a292_11ea_b7a8_351e50286832row10_col0" class="data row10 col0" >for</td>
#                         <td id="T_c57e9d98_a292_11ea_b7a8_351e50286832row10_col1" class="data row10 col1" >1854</td>
#             </tr>
#             <tr>
#                         <th id="T_c57e9d98_a292_11ea_b7a8_351e50286832level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_c57e9d98_a292_11ea_b7a8_351e50286832row11_col0" class="data row11 col0" >im</td>
#                         <td id="T_c57e9d98_a292_11ea_b7a8_351e50286832row11_col1" class="data row11 col1" >1676</td>
#             </tr>
#             <tr>
#                         <th id="T_c57e9d98_a292_11ea_b7a8_351e50286832level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_c57e9d98_a292_11ea_b7a8_351e50286832row12_col0" class="data row12 col0" >of</td>
#                         <td id="T_c57e9d98_a292_11ea_b7a8_351e50286832row12_col1" class="data row12 col1" >1638</td>
#             </tr>

# %%
fig = px.bar(temp, x="count", y="Common_words", title='Commmon Words in Selected Text', orientation='h', 
             width=700, height=700,color='Common_words')
fig.show()
# Out:
# <div>
#
#
#             <div id="bca52ff5-e06f-49b2-83d6-a9467c88f540" class="plotly-graph-div" style="height:700px; width:700px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bca52ff5-e06f-49b2-83d6-a9467c88f540")) {
#                     Plotly.newPlot(
#                         'bca52ff5-e06f-49b2-83d6-a9467c88f540',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "i", "marker": {"color": "#636efa"}, "name": "i", "offsetgroup": "i", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [7200], "xaxis": "x", "y": ["i"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "to", "marker": {"color": "#EF553B"}, "name": "to", "offsetgroup": "to", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [5305], "xaxis": "x", "y": ["to"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "the", "marker": {"color": "#00cc96"}, "name": "the", "offsetgroup": "the", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [4590], "xaxis": "x", "y": ["the"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "a", "marker": {"color": "#ab63fa"}, "name": "a", "offsetgroup": "a", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [3538], "xaxis": "x", "y": ["a"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "my", "marker": {"color": "#FFA15A"}, "name": "my", "offsetgroup": "my", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2783], "xaxis": "x", "y": ["my"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "you", "marker": {"color": "#19d3f3"}, "name": "you", "offsetgroup": "you", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2624], "xaxis": "x", "y": ["you"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "and", "marker": {"color": "#FF6692"}, "name": "and", "offsetgroup": "and", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2321], "xaxis": "x", "y": ["and"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "it", "marker": {"color": "#B6E880"}, "name": "it", "offsetgroup": "it", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2158], "xaxis": "x", "y": ["it"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "is", "marker": {"color": "#FF97FF"}, "name": "is", "offsetgroup": "is", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2115], "xaxis": "x", "y": ["is"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "in", "marker": {"color": "#FECB52"}, "name": "in", "offsetgroup": "in", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [1986], "xaxis": "x", "y": ["in"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "for", "marker": {"color": "#636efa"}, "name": "for", "offsetgroup": "for", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [1854], "xaxis": "x", "y": ["for"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "im", "marker": {"color": "#EF553B"}, "name": "im", "offsetgroup": "im", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [1676], " ...
#                         {"barmode": "relative", "height": 700, "legend": {"title": {"text": "Common_words"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewid

# %% [markdown]
# OOPS!While we cleaned our dataset we didnt remove the stop words and hence we can see the most coomon word is 'to' . Let's try again after removing the stopwords

# %%
def remove_stopword(x):
    return [y for y in x if y not in stopwords.words('english')]
train['temp_list'] = train['temp_list'].apply(lambda x:remove_stopword(x))

# %%
top = Counter([item for sublist in train['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp = temp.iloc[1:,:]
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Purples')
# Out:
# <style  type="text/css" >
#     #T_d901e906_a292_11ea_b7a8_351e50286832row0_col1 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_d901e906_a292_11ea_b7a8_351e50286832row1_col1 {
#             background-color:  #6c55a5;
#             color:  #f1f1f1;
#         }    #T_d901e906_a292_11ea_b7a8_351e50286832row2_col1 {
#             background-color:  #9692c4;
#             color:  #000000;
#         }    #T_d901e906_a292_11ea_b7a8_351e50286832row3_col1 {
#             background-color:  #a9a7cf;
#             color:  #000000;
#         }    #T_d901e906_a292_11ea_b7a8_351e50286832row4_col1 {
#             background-color:  #c2c3df;
#             color:  #000000;
#         }    #T_d901e906_a292_11ea_b7a8_351e50286832row5_col1 {
#             background-color:  #c3c4e0;
#             color:  #000000;
#         }    #T_d901e906_a292_11ea_b7a8_351e50286832row6_col1 {
#             background-color:  #c5c6e1;
#             color:  #000000;
#         }    #T_d901e906_a292_11ea_b7a8_351e50286832row7_col1 {
#             background-color:  #dadaeb;
#             color:  #000000;
#         }    #T_d901e906_a292_11ea_b7a8_351e50286832row8_col1 {
#             background-color:  #efedf5;
#             color:  #000000;
#         }    #T_d901e906_a292_11ea_b7a8_351e50286832row9_col1 {
#             background-color:  #efedf5;
#             color:  #000000;
#         }    #T_d901e906_a292_11ea_b7a8_351e50286832row10_col1 {
#             background-color:  #f2f0f7;
#             color:  #000000;
#         }    #T_d901e906_a292_11ea_b7a8_351e50286832row11_col1 {
#             background-color:  #f6f4f9;
#             color:  #000000;
#         }    #T_d901e906_a292_11ea_b7a8_351e50286832row12_col1 {
#             background-color:  #f7f5fa;
#             color:  #000000;
#         }    #T_d901e906_a292_11ea_b7a8_351e50286832row13_col1 {
#             background-color:  #faf8fb;
#             color:  #000000;
#         }    #T_d901e906_a292_11ea_b7a8_351e50286832row14_col1 {
#             background-color:  #faf9fc;
#             color:  #000000;
#         }    #T_d901e906_a292_11ea_b7a8_351e50286832row15_col1 {
#             background-color:  #faf9fc;
#             color:  #000000;
#         }    #T_d901e906_a292_11ea_b7a8_351e50286832row16_col1 {
#             background-color:  #fbfafc;
#             color:  #000000;
#         }    #T_d901e906_a292_11ea_b7a8_351e50286832row17_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_d901e906_a292_11ea_b7a8_351e50286832row18_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }</style><table id="T_d901e906_a292_11ea_b7a8_351e50286832" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Common_words</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d901e906_a292_11ea_b7a8_351e50286832level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_d901e906_a292_11ea_b7a8_351e50286832row0_col0" class="data row0 col0" >good</td>
#                         <td id="T_d901e906_a292_11ea_b7a8_351e50286832row0_col1" class="data row0 col1" >1251</td>
#             </tr>
#             <tr>
#                         <th id="T_d901e906_a292_11ea_b7a8_351e50286832level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_d901e906_a292_11ea_b7a8_351e50286832row1_col0" class="data row1 col0" >day</td>
#                         <td id="T_d901e906_a292_11ea_b7a8_351e50286832row1_col1" class="data row1 col1" >1058</td>
#             </tr>
#             <tr>
#                         <th id="T_d901e906_a292_11ea_b7a8_351e50286832level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_d901e906_a292_11ea_b7a8_351e50286832row2_col0" class="data row2 col0" >love</td>
#                         <td id="T_d901e906_a292_11ea_b7a8_351e50286832row2_col1" class="data row2 col1" >909</td>
#             </tr>
#             <tr>
#                         <th id="T_d901e906_a292_11ea_b7a8_351e50286832level0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_d901e906_a292_11ea_b7a8_351e50286832row3_col0" class="data row3 col0" >happy</td>
#                         <td id="T_d901e906_a292_11ea_b7a8_351e50286832row3_col1" class="data row3 col1" >852</td>
#             </tr>
#             <tr>
#                         <th id="T_d901e906_a292_11ea_b7a8_351e50286832level0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_d901e906_a292_11ea_b7a8_351e50286832row4_col0" class="data row4 col0" >like</td>
#                         <td id="T_d901e906_a292_11ea_b7a8_351e50286832row4_col1" class="data row4 col1" >774</td>
#             </tr>
#             <tr>
#                         <th id="T_d901e906_a292_11ea_b7a8_351e50286832level0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_d901e906_a292_11ea_b7a8_351e50286832row5_col0" class="data row5 col0" >get</td>
#                         <td id="T_d901e906_a292_11ea_b7a8_351e50286832row5_col1" class="data row5 col1" >772</td>
#             </tr>
#             <tr>
#                         <th id="T_d901e906_a292_11ea_b7a8_351e50286832level0_row6" class="row_heading level0 row6" >7</th>
#                         <td id="T_d901e906_a292_11ea_b7a8_351e50286832row6_col0" class="data row6 col0" >dont</td>
#                         <td id="T_d901e906_a292_11ea_b7a8_351e50286832row6_col1" class="data row6 col1" >765</td>
#             </tr>
#             <tr>
#                         <th id="T_d901e906_a292_11ea_b7a8_351e50286832level0_row7" class="row_heading level0 row7" >8</th>
#                         <td id="T_d901e906_a292_11ea_b7a8_351e50286832row7_col0" class="data row7 col0" >go</td>
#                         <td id="T_d901e906_a292_11ea_b7a8_351e50286832row7_col1" class="data row7 col1" >700</td>
#             </tr>
#             <tr>
#                         <th id="T_d901e906_a292_11ea_b7a8_351e50286832level0_row8" class="row_heading level0 row8" >9</th>
#                         <td id="T_d901e906_a292_11ea_b7a8_351e50286832row8_col0" class="data row8 col0" >cant</td>
#                         <td id="T_d901e906_a292_11ea_b7a8_351e50286832row8_col1" class="data row8 col1" >613</td>
#             </tr>
#             <tr>
#                         <th id="T_d901e906_a292_11ea_b7a8_351e50286832level0_row9" class="row_heading level0 row9" >10</th>
#                         <td id="T_d901e906_a292_11ea_b7a8_351e50286832row9_col0" class="data row9 col0" >work</td>
#                         <td id="T_d901e906_a292_11ea_b7a8_351e50286832row9_col1" class="data row9 col1" >612</td>
#             </tr>
#             <tr>
#                         <th id="T_d901e906_a292_11ea_b7a8_351e50286832level0_row10" class="row_heading level0 row10" >11</th>
#                         <td id="T_d901e906_a292_11ea_b7a8_351e50286832row10_col0" class="data row10 col0" >going</td>
#                         <td id="T_d901e906_a292_11ea_b7a8_351e50286832row10_col1" class="data row10 col1" >592</td>
#             </tr>
#             <tr>
#                         <th id="T_d901e906_a292_11ea_b7a8_351e50286832level0_row11" class="row_heading level0 row11" >12</th>
#                         <td id="T_d901e906_a292_11ea_b7a8_351e50286832row11_col0" class="data row11 col0" >today</td>
#                         <td id="T_d901e906_a292_11ea_b7a8_351e50286832row11_col1" class="data row11 col1" >564</td>
#             </tr>
#             <tr>
#                         <th id="T_d901e906_a292_11ea_b7a8_351e50286832level0_row12" class="row_heading level0 row12" >13</th>
#                         <td id="T_d901e906_a292_11ea_b7a8_351e50286832row12_col0" class="data row12 col0" >got</td>
#                         <td id="T_d901e906_a292_11ea_b7a8_351e50286832row12_col1" class="data row12 col1" >558</td>
#             </tr>
#             <tr>
#                         <th id="T_d901e906_a292_11ea_b7a8_351e50286832level0_row13" class="row_heading level

# %%
fig = px.treemap(temp, path=['Common_words'], values='count',title='Tree of Most Common Words')
fig.show()
# Out:
# <div>
#
#
#             <div id="2eca91ef-780b-4dcf-8384-519498dbd75d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2eca91ef-780b-4dcf-8384-519498dbd75d")) {
#                     Plotly.newPlot(
#                         '2eca91ef-780b-4dcf-8384-519498dbd75d',
#                         [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hoverlabel": {"namelength": 0}, "hovertemplate": "labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}", "ids": ["cant", "day", "dont", "get", "go", "going", "good", "got", "happy", "like", "lol", "love", "one", "really", "thanks", "time", "today", "u", "work"], "labels": ["cant", "day", "dont", "get", "go", "going", "good", "got", "happy", "like", "lol", "love", "one", "really", "thanks", "time", "today", "u", "work"], "name": "", "parents": ["", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", ""], "type": "treemap", "values": [613, 1058, 765, 772, 700, 592, 1251, 558, 852, 774, 528, 909, 538, 520, 532, 534, 564, 519, 612]}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterterna ...

# %% [markdown]
# # Most Common words in Text
#
# Let's also look at the most common words in Text

# %%
train['temp_list1'] = train['text'].apply(lambda x:str(x).split()) #List of words in every row for text
train['temp_list1'] = train['temp_list1'].apply(lambda x:remove_stopword(x)) #Removing Stopwords

# %%
top = Counter([item for sublist in train['temp_list1'] for item in sublist])
temp = pd.DataFrame(top.most_common(25))
temp = temp.iloc[1:,:]
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
#     #T_fa36cd30_a292_11ea_b7a8_351e50286832row0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_fa36cd30_a292_11ea_b7a8_351e50286832row1_col1 {
#             background-color:  #4292c6;
#             color:  #000000;
#         }    #T_fa36cd30_a292_11ea_b7a8_351e50286832row2_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_fa36cd30_a292_11ea_b7a8_351e50286832row3_col1 {
#             background-color:  #79b5d9;
#             color:  #000000;
#         }    #T_fa36cd30_a292_11ea_b7a8_351e50286832row4_col1 {
#             background-color:  #92c4de;
#             color:  #000000;
#         }    #T_fa36cd30_a292_11ea_b7a8_351e50286832row5_col1 {
#             background-color:  #a5cde3;
#             color:  #000000;
#         }    #T_fa36cd30_a292_11ea_b7a8_351e50286832row6_col1 {
#             background-color:  #b8d5ea;
#             color:  #000000;
#         }    #T_fa36cd30_a292_11ea_b7a8_351e50286832row7_col1 {
#             background-color:  #bad6eb;
#             color:  #000000;
#         }    #T_fa36cd30_a292_11ea_b7a8_351e50286832row8_col1 {
#             background-color:  #bed8ec;
#             color:  #000000;
#         }    #T_fa36cd30_a292_11ea_b7a8_351e50286832row9_col1 {
#             background-color:  #bed8ec;
#             color:  #000000;
#         }    #T_fa36cd30_a292_11ea_b7a8_351e50286832row10_col1 {
#             background-color:  #c4daee;
#             color:  #000000;
#         }    #T_fa36cd30_a292_11ea_b7a8_351e50286832row11_col1 {
#             background-color:  #cddff1;
#             color:  #000000;
#         }    #T_fa36cd30_a292_11ea_b7a8_351e50286832row12_col1 {
#             background-color:  #d3e4f3;
#             color:  #000000;
#         }    #T_fa36cd30_a292_11ea_b7a8_351e50286832row13_col1 {
#             background-color:  #d4e4f4;
#             color:  #000000;
#         }    #T_fa36cd30_a292_11ea_b7a8_351e50286832row14_col1 {
#             background-color:  #d7e6f5;
#             color:  #000000;
#         }    #T_fa36cd30_a292_11ea_b7a8_351e50286832row15_col1 {
#             background-color:  #d8e7f5;
#             color:  #000000;
#         }    #T_fa36cd30_a292_11ea_b7a8_351e50286832row16_col1 {
#             background-color:  #dae8f6;
#             color:  #000000;
#         }    #T_fa36cd30_a292_11ea_b7a8_351e50286832row17_col1 {
#             background-color:  #dbe9f6;
#             color:  #000000;
#         }    #T_fa36cd30_a292_11ea_b7a8_351e50286832row18_col1 {
#             background-color:  #ddeaf7;
#             color:  #000000;
#         }    #T_fa36cd30_a292_11ea_b7a8_351e50286832row19_col1 {
#             background-color:  #dfecf7;
#             color:  #000000;
#         }    #T_fa36cd30_a292_11ea_b7a8_351e50286832row20_col1 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_fa36cd30_a292_11ea_b7a8_351e50286832row21_col1 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_fa36cd30_a292_11ea_b7a8_351e50286832row22_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_fa36cd30_a292_11ea_b7a8_351e50286832row23_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }</style><table id="T_fa36cd30_a292_11ea_b7a8_351e50286832" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Common_words</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fa36cd30_a292_11ea_b7a8_351e50286832level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_fa36cd30_a292_11ea_b7a8_351e50286832row0_col0" class="data row0 col0" >day</td>
#                         <td id="T_fa36cd30_a292_11ea_b7a8_351e50286832row0_col1" class="data row0 col1" >2044</td>
#             </tr>
#             <tr>
#                         <th id="T_fa36cd30_a292_11ea_b7a8_351e50286832level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_fa36cd30_a292_11ea_b7a8_351e50286832row1_col0" class="data row1 col0" >good</td>
#                         <td id="T_fa36cd30_a292_11ea_b7a8_351e50286832row1_col1" class="data row1 col1" >1549</td>
#             </tr>
#             <tr>
#                         <th id="T_fa36cd30_a292_11ea_b7a8_351e50286832level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_fa36cd30_a292_11ea_b7a8_351e50286832row2_col0" class="data row2 col0" >get</td>
#                         <td id="T_fa36cd30_a292_11ea_b7a8_351e50286832row2_col1" class="data row2 col1" >1426</td>
#             </tr>
#             <tr>
#                         <th id="T_fa36cd30_a292_11ea_b7a8_351e50286832level0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_fa36cd30_a292_11ea_b7a8_351e50286832row3_col0" class="data row3 col0" >like</td>
#                         <td id="T_fa36cd30_a292_11ea_b7a8_351e50286832row3_col1" class="data row3 col1" >1346</td>
#             </tr>
#             <tr>
#                         <th id="T_fa36cd30_a292_11ea_b7a8_351e50286832level0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_fa36cd30_a292_11ea_b7a8_351e50286832row4_col0" class="data row4 col0" >go</td>
#                         <td id="T_fa36cd30_a292_11ea_b7a8_351e50286832row4_col1" class="data row4 col1" >1267</td>
#             </tr>
#             <tr>
#                         <th id="T_fa36cd30_a292_11ea_b7a8_351e50286832level0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_fa36cd30_a292_11ea_b7a8_351e50286832row5_col0" class="data row5 col0" >dont</td>
#                         <td id="T_fa36cd30_a292_11ea_b7a8_351e50286832row5_col1" class="data row5 col1" >1200</td>
#             </tr>
#             <tr>
#                         <th id="T_fa36cd30_a292_11ea_b7a8_351e50286832level0_row6" class="row_heading level0 row6" >7</th>
#                         <td id="T_fa36cd30_a292_11ea_b7a8_351e50286832row6_col0" class="data row6 col0" >love</td>
#                         <td id="T_fa36cd30_a292_11ea_b7a8_351e50286832row6_col1" class="data row6 col1" >1122</td>
#             </tr>
#             <tr>
#                         <th id="T_fa36cd30_a292_11ea_b7a8_351e50286832level0_row7" class="row_heading level0 row7" >8</th>
#                         <td id="T_fa36cd30_a292_11ea_b7a8_351e50286832row7_col0" class="data row7 col0" >work</td>
#                         <td id="T_fa36cd30_a292_11ea_b7a8_351e50286832row7_col1" class="data row7 col1" >1112</td>
#             </tr>
#             <tr>
#                         <th id="T_fa36cd30_a292_11ea_b7a8_351e50286832level0_row8" class="row_heading level0 row8" >9</th>
#                         <td id="T_fa36cd30_a292_11ea_b7a8_351e50286832row8_col0" class="data row8 col0" >going</td>
#                         <td id="T_fa36cd30_a292_11ea_b7a8_351e50286832row8_col1" class="data row8 col1" >1096</td>
#             </tr>
#             <tr>
#                         <th id="T_fa36cd30_a292_11ea_b7a8_351e50286832level0_row9" class="row_heading level0 row9" >10</th>
#                         <td id="T_fa36cd30_a292_11ea_b7a8_351e50286832row9_col0" class="data row9 col0" >today</td>
#                         <td id="T_fa36cd30_a292_11ea_b7a8_351e50286832row9_col1" class="data row9 col1" >1096</td>
#             </tr>
#             <tr>
#                         <th id="T_fa36cd30_a292_11ea_b7a8_351e50286832level0_row10" class="row_heading level0 row10" >11</th>
#                         <td id="T_fa36cd30_a292_11ea_b7a8_351e50286832row10_col0" class="data row10 col0" >got</td>
#                         <td id="T_fa36cd30_a292_11ea_b7a8_351e50286832row10_col1" class="data row10 col1" >1072</td>
#             </tr>
#             <tr>
#                         <th id="T_fa36cd30_a292_11ea_b7a8_351e50286832level0_row11" class="row_heading level0 row11" >12</th>
#                         <td id="T_fa36cd30_a292_11ea_b7a8_351e50286832row11_col0" class="dat

# %% [markdown]
# So the first two common word was I'm so I removed it and took data from second row

# %%
fig = px.bar(temp, x="count", y="Common_words", title='Commmon Words in Text', orientation='h', 
             width=700, height=700,color='Common_words')
fig.show()
# Out:
# <div>
#
#
#             <div id="8812c330-d8ea-4516-9a69-77256803a881" class="plotly-graph-div" style="height:700px; width:700px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8812c330-d8ea-4516-9a69-77256803a881")) {
#                     Plotly.newPlot(
#                         '8812c330-d8ea-4516-9a69-77256803a881',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "day", "marker": {"color": "#636efa"}, "name": "day", "offsetgroup": "day", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2044], "xaxis": "x", "y": ["day"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "good", "marker": {"color": "#EF553B"}, "name": "good", "offsetgroup": "good", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [1549], "xaxis": "x", "y": ["good"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "get", "marker": {"color": "#00cc96"}, "name": "get", "offsetgroup": "get", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [1426], "xaxis": "x", "y": ["get"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "like", "marker": {"color": "#ab63fa"}, "name": "like", "offsetgroup": "like", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [1346], "xaxis": "x", "y": ["like"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "go", "marker": {"color": "#FFA15A"}, "name": "go", "offsetgroup": "go", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [1267], "xaxis": "x", "y": ["go"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "dont", "marker": {"color": "#19d3f3"}, "name": "dont", "offsetgroup": "dont", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [1200], "xaxis": "x", "y": ["dont"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "love", "marker": {"color": "#FF6692"}, "name": "love", "offsetgroup": "love", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [1122], "xaxis": "x", "y": ["love"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "work", "marker": {"color": "#B6E880"}, "name": "work", "offsetgroup": "work", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [1112], "xaxis": "x", "y": ["work"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "going", "marker": {"color": "#FF97FF"}, "name": "going", "offsetgroup": "going", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [1096], "xaxis": "x", "y": ["going"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "today", "marker": {"color": "#FECB52"}, "name": "today", "offsetgroup": "today", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [1096], "xaxis": "x", "y": ["today"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "got", "marker": {"color": "#636efa"}, "name": "got", "offsetgroup": "got", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [1072], "xaxis": "x", "y": ["got"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "cant", "marker": {"color": "#EF553B"}, "name": "cant", "offsetgroup": "cant", "orientation": "h", ...

# %% [markdown]
# SO we can see the Most common words in Selected text and Text are almost the same,which was obvious

# %% [markdown]
# # Most common words Sentiments Wise
#
# Let's look at the most common words in different sentiments

# %%
Positive_sent = train[train['sentiment']=='positive']
Negative_sent = train[train['sentiment']=='negative']
Neutral_sent = train[train['sentiment']=='neutral']

# %%
#MosT common positive words
top = Counter([item for sublist in Positive_sent['temp_list'] for item in sublist])
temp_positive = pd.DataFrame(top.most_common(20))
temp_positive.columns = ['Common_words','count']
temp_positive.style.background_gradient(cmap='Greens')
# Out:
# <style  type="text/css" >
#     #T_fabc6b98_a292_11ea_b7a8_351e50286832row0_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_fabc6b98_a292_11ea_b7a8_351e50286832row1_col1 {
#             background-color:  #026f2e;
#             color:  #f1f1f1;
#         }    #T_fabc6b98_a292_11ea_b7a8_351e50286832row2_col1 {
#             background-color:  #107a37;
#             color:  #f1f1f1;
#         }    #T_fabc6b98_a292_11ea_b7a8_351e50286832row3_col1 {
#             background-color:  #7cc87c;
#             color:  #000000;
#         }    #T_fabc6b98_a292_11ea_b7a8_351e50286832row4_col1 {
#             background-color:  #86cc85;
#             color:  #000000;
#         }    #T_fabc6b98_a292_11ea_b7a8_351e50286832row5_col1 {
#             background-color:  #aadda4;
#             color:  #000000;
#         }    #T_fabc6b98_a292_11ea_b7a8_351e50286832row6_col1 {
#             background-color:  #cbeac4;
#             color:  #000000;
#         }    #T_fabc6b98_a292_11ea_b7a8_351e50286832row7_col1 {
#             background-color:  #d1edcb;
#             color:  #000000;
#         }    #T_fabc6b98_a292_11ea_b7a8_351e50286832row8_col1 {
#             background-color:  #d4eece;
#             color:  #000000;
#         }    #T_fabc6b98_a292_11ea_b7a8_351e50286832row9_col1 {
#             background-color:  #d9f0d3;
#             color:  #000000;
#         }    #T_fabc6b98_a292_11ea_b7a8_351e50286832row10_col1 {
#             background-color:  #ddf2d8;
#             color:  #000000;
#         }    #T_fabc6b98_a292_11ea_b7a8_351e50286832row11_col1 {
#             background-color:  #eaf7e6;
#             color:  #000000;
#         }    #T_fabc6b98_a292_11ea_b7a8_351e50286832row12_col1 {
#             background-color:  #ebf7e7;
#             color:  #000000;
#         }    #T_fabc6b98_a292_11ea_b7a8_351e50286832row13_col1 {
#             background-color:  #edf8ea;
#             color:  #000000;
#         }    #T_fabc6b98_a292_11ea_b7a8_351e50286832row14_col1 {
#             background-color:  #f0f9ed;
#             color:  #000000;
#         }    #T_fabc6b98_a292_11ea_b7a8_351e50286832row15_col1 {
#             background-color:  #f1faee;
#             color:  #000000;
#         }    #T_fabc6b98_a292_11ea_b7a8_351e50286832row16_col1 {
#             background-color:  #f4fbf2;
#             color:  #000000;
#         }    #T_fabc6b98_a292_11ea_b7a8_351e50286832row17_col1 {
#             background-color:  #f5fbf3;
#             color:  #000000;
#         }    #T_fabc6b98_a292_11ea_b7a8_351e50286832row18_col1 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_fabc6b98_a292_11ea_b7a8_351e50286832row19_col1 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }</style><table id="T_fabc6b98_a292_11ea_b7a8_351e50286832" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Common_words</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fabc6b98_a292_11ea_b7a8_351e50286832level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_fabc6b98_a292_11ea_b7a8_351e50286832row0_col0" class="data row0 col0" >good</td>
#                         <td id="T_fabc6b98_a292_11ea_b7a8_351e50286832row0_col1" class="data row0 col1" >826</td>
#             </tr>
#             <tr>
#                         <th id="T_fabc6b98_a292_11ea_b7a8_351e50286832level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_fabc6b98_a292_11ea_b7a8_351e50286832row1_col0" class="data row1 col0" >happy</td>
#                         <td id="T_fabc6b98_a292_11ea_b7a8_351e50286832row1_col1" class="data row1 col1" >730</td>
#             </tr>
#             <tr>
#                         <th id="T_fabc6b98_a292_11ea_b7a8_351e50286832level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_fabc6b98_a292_11ea_b7a8_351e50286832row2_col0" class="data row2 col0" >love</td>
#                         <td id="T_fabc6b98_a292_11ea_b7a8_351e50286832row2_col1" class="data row2 col1" >697</td>
#             </tr>
#             <tr>
#                         <th id="T_fabc6b98_a292_11ea_b7a8_351e50286832level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_fabc6b98_a292_11ea_b7a8_351e50286832row3_col0" class="data row3 col0" >day</td>
#                         <td id="T_fabc6b98_a292_11ea_b7a8_351e50286832row3_col1" class="data row3 col1" >456</td>
#             </tr>
#             <tr>
#                         <th id="T_fabc6b98_a292_11ea_b7a8_351e50286832level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_fabc6b98_a292_11ea_b7a8_351e50286832row4_col0" class="data row4 col0" >thanks</td>
#                         <td id="T_fabc6b98_a292_11ea_b7a8_351e50286832row4_col1" class="data row4 col1" >439</td>
#             </tr>
#             <tr>
#                         <th id="T_fabc6b98_a292_11ea_b7a8_351e50286832level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_fabc6b98_a292_11ea_b7a8_351e50286832row5_col0" class="data row5 col0" >great</td>
#                         <td id="T_fabc6b98_a292_11ea_b7a8_351e50286832row5_col1" class="data row5 col1" >364</td>
#             </tr>
#             <tr>
#                         <th id="T_fabc6b98_a292_11ea_b7a8_351e50286832level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_fabc6b98_a292_11ea_b7a8_351e50286832row6_col0" class="data row6 col0" >fun</td>
#                         <td id="T_fabc6b98_a292_11ea_b7a8_351e50286832row6_col1" class="data row6 col1" >287</td>
#             </tr>
#             <tr>
#                         <th id="T_fabc6b98_a292_11ea_b7a8_351e50286832level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_fabc6b98_a292_11ea_b7a8_351e50286832row7_col0" class="data row7 col0" >nice</td>
#                         <td id="T_fabc6b98_a292_11ea_b7a8_351e50286832row7_col1" class="data row7 col1" >267</td>
#             </tr>
#             <tr>
#                         <th id="T_fabc6b98_a292_11ea_b7a8_351e50286832level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_fabc6b98_a292_11ea_b7a8_351e50286832row8_col0" class="data row8 col0" >mothers</td>
#                         <td id="T_fabc6b98_a292_11ea_b7a8_351e50286832row8_col1" class="data row8 col1" >259</td>
#             </tr>
#             <tr>
#                         <th id="T_fabc6b98_a292_11ea_b7a8_351e50286832level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_fabc6b98_a292_11ea_b7a8_351e50286832row9_col0" class="data row9 col0" >hope</td>
#                         <td id="T_fabc6b98_a292_11ea_b7a8_351e50286832row9_col1" class="data row9 col1" >245</td>
#             </tr>
#             <tr>
#                         <th id="T_fabc6b98_a292_11ea_b7a8_351e50286832level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_fabc6b98_a292_11ea_b7a8_351e50286832row10_col0" class="data row10 col0" >awesome</td>
#                         <td id="T_fabc6b98_a292_11ea_b7a8_351e50286832row10_col1" class="data row10 col1" >232</td>
#             </tr>
#             <tr>
#                         <th id="T_fabc6b98_a292_11ea_b7a8_351e50286832level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_fabc6b98_a292_11ea_b7a8_351e50286832row11_col0" class="data row11 col0" >im</td>
#                         <td id="T_fabc6b98_a292_11ea_b7a8_351e50286832row11_col1" class="data row11 col1" >185</td>
#             </tr>
#             <tr>
#                         <th id="T_fabc6b98_a292_11ea_b7a8_351e50286832level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_fabc6b98_a292_11ea_b7a8_351e50286832row12_col0" class="data row12 col0" >thank</td>
#                         <td id="T_fabc6b98_a292_11ea_b7a8_351e50286832row12_col1" class="data row12 col1" >180</td>

# %%
fig = px.bar(temp_positive, x="count", y="Common_words", title='Most Commmon Positive Words', orientation='h', 
             width=700, height=700,color='Common_words')
fig.show()
# Out:
# <div>
#
#
#             <div id="6650f042-5222-4a3a-9b79-5be17009009f" class="plotly-graph-div" style="height:700px; width:700px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6650f042-5222-4a3a-9b79-5be17009009f")) {
#                     Plotly.newPlot(
#                         '6650f042-5222-4a3a-9b79-5be17009009f',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "good", "marker": {"color": "#636efa"}, "name": "good", "offsetgroup": "good", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [826], "xaxis": "x", "y": ["good"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "happy", "marker": {"color": "#EF553B"}, "name": "happy", "offsetgroup": "happy", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [730], "xaxis": "x", "y": ["happy"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "love", "marker": {"color": "#00cc96"}, "name": "love", "offsetgroup": "love", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [697], "xaxis": "x", "y": ["love"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "day", "marker": {"color": "#ab63fa"}, "name": "day", "offsetgroup": "day", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [456], "xaxis": "x", "y": ["day"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "thanks", "marker": {"color": "#FFA15A"}, "name": "thanks", "offsetgroup": "thanks", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [439], "xaxis": "x", "y": ["thanks"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "great", "marker": {"color": "#19d3f3"}, "name": "great", "offsetgroup": "great", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [364], "xaxis": "x", "y": ["great"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "fun", "marker": {"color": "#FF6692"}, "name": "fun", "offsetgroup": "fun", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [287], "xaxis": "x", "y": ["fun"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "nice", "marker": {"color": "#B6E880"}, "name": "nice", "offsetgroup": "nice", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [267], "xaxis": "x", "y": ["nice"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "mothers", "marker": {"color": "#FF97FF"}, "name": "mothers", "offsetgroup": "mothers", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [259], "xaxis": "x", "y": ["mothers"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "hope", "marker": {"color": "#FECB52"}, "name": "hope", "offsetgroup": "hope", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [245], "xaxis": "x", "y": ["hope"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "awesome", "marker": {"color": "#636efa"}, "name": "awesome", "offsetgroup": "awesome", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [232], "xaxis": "x", "y": ["awesome"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "im", "marker": {"color": "#EF553B"}, "name": "im", "offsetgroup" ...
#                         {"barmode": "relative", "height": 700, "legend": {"title": {"text": "Common_words"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "

# %%
#MosT common negative words
top = Counter([item for sublist in Negative_sent['temp_list'] for item in sublist])
temp_negative = pd.DataFrame(top.most_common(20))
temp_negative = temp_negative.iloc[1:,:]
temp_negative.columns = ['Common_words','count']
temp_negative.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_fb2b5f62_a292_11ea_b7a8_351e50286832row0_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_fb2b5f62_a292_11ea_b7a8_351e50286832row1_col1 {
#             background-color:  #820711;
#             color:  #f1f1f1;
#         }    #T_fb2b5f62_a292_11ea_b7a8_351e50286832row2_col1 {
#             background-color:  #c2161b;
#             color:  #f1f1f1;
#         }    #T_fb2b5f62_a292_11ea_b7a8_351e50286832row3_col1 {
#             background-color:  #f44f39;
#             color:  #000000;
#         }    #T_fb2b5f62_a292_11ea_b7a8_351e50286832row4_col1 {
#             background-color:  #fa6648;
#             color:  #000000;
#         }    #T_fb2b5f62_a292_11ea_b7a8_351e50286832row5_col1 {
#             background-color:  #fb7252;
#             color:  #000000;
#         }    #T_fb2b5f62_a292_11ea_b7a8_351e50286832row6_col1 {
#             background-color:  #fc8a6a;
#             color:  #000000;
#         }    #T_fb2b5f62_a292_11ea_b7a8_351e50286832row7_col1 {
#             background-color:  #fcb79c;
#             color:  #000000;
#         }    #T_fb2b5f62_a292_11ea_b7a8_351e50286832row8_col1 {
#             background-color:  #fcbca2;
#             color:  #000000;
#         }    #T_fb2b5f62_a292_11ea_b7a8_351e50286832row9_col1 {
#             background-color:  #fcbfa7;
#             color:  #000000;
#         }    #T_fb2b5f62_a292_11ea_b7a8_351e50286832row10_col1 {
#             background-color:  #fcc1a8;
#             color:  #000000;
#         }    #T_fb2b5f62_a292_11ea_b7a8_351e50286832row11_col1 {
#             background-color:  #fdd0bc;
#             color:  #000000;
#         }    #T_fb2b5f62_a292_11ea_b7a8_351e50286832row12_col1 {
#             background-color:  #fed8c7;
#             color:  #000000;
#         }    #T_fb2b5f62_a292_11ea_b7a8_351e50286832row13_col1 {
#             background-color:  #fee2d5;
#             color:  #000000;
#         }    #T_fb2b5f62_a292_11ea_b7a8_351e50286832row14_col1 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_fb2b5f62_a292_11ea_b7a8_351e50286832row15_col1 {
#             background-color:  #ffede5;
#             color:  #000000;
#         }    #T_fb2b5f62_a292_11ea_b7a8_351e50286832row16_col1 {
#             background-color:  #ffeee7;
#             color:  #000000;
#         }    #T_fb2b5f62_a292_11ea_b7a8_351e50286832row17_col1 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_fb2b5f62_a292_11ea_b7a8_351e50286832row18_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_fb2b5f62_a292_11ea_b7a8_351e50286832" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Common_words</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fb2b5f62_a292_11ea_b7a8_351e50286832level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_fb2b5f62_a292_11ea_b7a8_351e50286832row0_col0" class="data row0 col0" >miss</td>
#                         <td id="T_fb2b5f62_a292_11ea_b7a8_351e50286832row0_col1" class="data row0 col1" >358</td>
#             </tr>
#             <tr>
#                         <th id="T_fb2b5f62_a292_11ea_b7a8_351e50286832level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_fb2b5f62_a292_11ea_b7a8_351e50286832row1_col0" class="data row1 col0" >sad</td>
#                         <td id="T_fb2b5f62_a292_11ea_b7a8_351e50286832row1_col1" class="data row1 col1" >343</td>
#             </tr>
#             <tr>
#                         <th id="T_fb2b5f62_a292_11ea_b7a8_351e50286832level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_fb2b5f62_a292_11ea_b7a8_351e50286832row2_col0" class="data row2 col0" >sorry</td>
#                         <td id="T_fb2b5f62_a292_11ea_b7a8_351e50286832row2_col1" class="data row2 col1" >300</td>
#             </tr>
#             <tr>
#                         <th id="T_fb2b5f62_a292_11ea_b7a8_351e50286832level0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_fb2b5f62_a292_11ea_b7a8_351e50286832row3_col0" class="data row3 col0" >bad</td>
#                         <td id="T_fb2b5f62_a292_11ea_b7a8_351e50286832row3_col1" class="data row3 col1" >246</td>
#             </tr>
#             <tr>
#                         <th id="T_fb2b5f62_a292_11ea_b7a8_351e50286832level0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_fb2b5f62_a292_11ea_b7a8_351e50286832row4_col0" class="data row4 col0" >hate</td>
#                         <td id="T_fb2b5f62_a292_11ea_b7a8_351e50286832row4_col1" class="data row4 col1" >230</td>
#             </tr>
#             <tr>
#                         <th id="T_fb2b5f62_a292_11ea_b7a8_351e50286832level0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_fb2b5f62_a292_11ea_b7a8_351e50286832row5_col0" class="data row5 col0" >dont</td>
#                         <td id="T_fb2b5f62_a292_11ea_b7a8_351e50286832row5_col1" class="data row5 col1" >221</td>
#             </tr>
#             <tr>
#                         <th id="T_fb2b5f62_a292_11ea_b7a8_351e50286832level0_row6" class="row_heading level0 row6" >7</th>
#                         <td id="T_fb2b5f62_a292_11ea_b7a8_351e50286832row6_col0" class="data row6 col0" >cant</td>
#                         <td id="T_fb2b5f62_a292_11ea_b7a8_351e50286832row6_col1" class="data row6 col1" >201</td>
#             </tr>
#             <tr>
#                         <th id="T_fb2b5f62_a292_11ea_b7a8_351e50286832level0_row7" class="row_heading level0 row7" >8</th>
#                         <td id="T_fb2b5f62_a292_11ea_b7a8_351e50286832row7_col0" class="data row7 col0" >sick</td>
#                         <td id="T_fb2b5f62_a292_11ea_b7a8_351e50286832row7_col1" class="data row7 col1" >166</td>
#             </tr>
#             <tr>
#                         <th id="T_fb2b5f62_a292_11ea_b7a8_351e50286832level0_row8" class="row_heading level0 row8" >9</th>
#                         <td id="T_fb2b5f62_a292_11ea_b7a8_351e50286832row8_col0" class="data row8 col0" >like</td>
#                         <td id="T_fb2b5f62_a292_11ea_b7a8_351e50286832row8_col1" class="data row8 col1" >162</td>
#             </tr>
#             <tr>
#                         <th id="T_fb2b5f62_a292_11ea_b7a8_351e50286832level0_row9" class="row_heading level0 row9" >10</th>
#                         <td id="T_fb2b5f62_a292_11ea_b7a8_351e50286832row9_col0" class="data row9 col0" >sucks</td>
#                         <td id="T_fb2b5f62_a292_11ea_b7a8_351e50286832row9_col1" class="data row9 col1" >159</td>
#             </tr>
#             <tr>
#                         <th id="T_fb2b5f62_a292_11ea_b7a8_351e50286832level0_row10" class="row_heading level0 row10" >11</th>
#                         <td id="T_fb2b5f62_a292_11ea_b7a8_351e50286832row10_col0" class="data row10 col0" >feel</td>
#                         <td id="T_fb2b5f62_a292_11ea_b7a8_351e50286832row10_col1" class="data row10 col1" >158</td>
#             </tr>
#             <tr>
#                         <th id="T_fb2b5f62_a292_11ea_b7a8_351e50286832level0_row11" class="row_heading level0 row11" >12</th>
#                         <td id="T_fb2b5f62_a292_11ea_b7a8_351e50286832row11_col0" class="data row11 col0" >tired</td>
#                         <td id="T_fb2b5f62_a292_11ea_b7a8_351e50286832row11_col1" class="data row11 col1" >144</td>
#             </tr>
#             <tr>
#                         <th id="T_fb2b5f62_a292_11ea_b7a8_351e50286832level0_row12" class="row_heading level0 row12" >13</th>
#                         <td id="T_fb2b5f62_a292_11ea_b7a8_351e50286832row12_col0" class="data row12 col0" >really</td>
#                         <td id="T_fb2b5f62_a292_11ea_b7a8_351e50286832row12_col1" class="data row12 col1" >137</td>
#             </tr>
#             <tr>
#                         <th id="T_fb2b5f62_a292_11ea_b7a8_351e50286832level0_row13" class="row_heading le

# %%
fig = px.treemap(temp_negative, path=['Common_words'], values='count',title='Tree Of Most Common Negative Words')
fig.show()
# Out:
# <div>
#
#
#             <div id="e1b9122f-b7c1-4abe-a888-c81e973ae6b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e1b9122f-b7c1-4abe-a888-c81e973ae6b6")) {
#                     Plotly.newPlot(
#                         'e1b9122f-b7c1-4abe-a888-c81e973ae6b6',
#                         [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hoverlabel": {"namelength": 0}, "hovertemplate": "labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}", "ids": ["bad", "bored", "cant", "day", "dont", "feel", "get", "good", "hate", "hurts", "like", "miss", "really", "sad", "sick", "sorry", "sucks", "tired", "work"], "labels": ["bad", "bored", "cant", "day", "dont", "feel", "get", "good", "hate", "hurts", "like", "miss", "really", "sad", "sick", "sorry", "sucks", "tired", "work"], "name": "", "parents": ["", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", ""], "type": "treemap", "values": [246, 115, 201, 110, 221, 158, 97, 127, 230, 108, 162, 358, 137, 343, 166, 300, 159, 144, 99]}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterterna ...

# %%
#MosT common Neutral words
top = Counter([item for sublist in Neutral_sent['temp_list'] for item in sublist])
temp_neutral = pd.DataFrame(top.most_common(20))
temp_neutral = temp_neutral.loc[1:,:]
temp_neutral.columns = ['Common_words','count']
temp_neutral.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_fb9a8284_a292_11ea_b7a8_351e50286832row0_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_fb9a8284_a292_11ea_b7a8_351e50286832row1_col1 {
#             background-color:  #ab1016;
#             color:  #f1f1f1;
#         }    #T_fb9a8284_a292_11ea_b7a8_351e50286832row2_col1 {
#             background-color:  #f24734;
#             color:  #000000;
#         }    #T_fb9a8284_a292_11ea_b7a8_351e50286832row3_col1 {
#             background-color:  #f6553c;
#             color:  #000000;
#         }    #T_fb9a8284_a292_11ea_b7a8_351e50286832row4_col1 {
#             background-color:  #f96245;
#             color:  #000000;
#         }    #T_fb9a8284_a292_11ea_b7a8_351e50286832row5_col1 {
#             background-color:  #fa6849;
#             color:  #000000;
#         }    #T_fb9a8284_a292_11ea_b7a8_351e50286832row6_col1 {
#             background-color:  #fc8060;
#             color:  #000000;
#         }    #T_fb9a8284_a292_11ea_b7a8_351e50286832row7_col1 {
#             background-color:  #fc8565;
#             color:  #000000;
#         }    #T_fb9a8284_a292_11ea_b7a8_351e50286832row8_col1 {
#             background-color:  #fc9474;
#             color:  #000000;
#         }    #T_fb9a8284_a292_11ea_b7a8_351e50286832row9_col1 {
#             background-color:  #fc9474;
#             color:  #000000;
#         }    #T_fb9a8284_a292_11ea_b7a8_351e50286832row10_col1 {
#             background-color:  #fca486;
#             color:  #000000;
#         }    #T_fb9a8284_a292_11ea_b7a8_351e50286832row11_col1 {
#             background-color:  #fcab8f;
#             color:  #000000;
#         }    #T_fb9a8284_a292_11ea_b7a8_351e50286832row12_col1 {
#             background-color:  #fcb095;
#             color:  #000000;
#         }    #T_fb9a8284_a292_11ea_b7a8_351e50286832row13_col1 {
#             background-color:  #fcb99f;
#             color:  #000000;
#         }    #T_fb9a8284_a292_11ea_b7a8_351e50286832row14_col1 {
#             background-color:  #fdccb8;
#             color:  #000000;
#         }    #T_fb9a8284_a292_11ea_b7a8_351e50286832row15_col1 {
#             background-color:  #fee4d8;
#             color:  #000000;
#         }    #T_fb9a8284_a292_11ea_b7a8_351e50286832row16_col1 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_fb9a8284_a292_11ea_b7a8_351e50286832row17_col1 {
#             background-color:  #ffece4;
#             color:  #000000;
#         }    #T_fb9a8284_a292_11ea_b7a8_351e50286832row18_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_fb9a8284_a292_11ea_b7a8_351e50286832" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Common_words</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fb9a8284_a292_11ea_b7a8_351e50286832level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_fb9a8284_a292_11ea_b7a8_351e50286832row0_col0" class="data row0 col0" >get</td>
#                         <td id="T_fb9a8284_a292_11ea_b7a8_351e50286832row0_col1" class="data row0 col1" >612</td>
#             </tr>
#             <tr>
#                         <th id="T_fb9a8284_a292_11ea_b7a8_351e50286832level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_fb9a8284_a292_11ea_b7a8_351e50286832row1_col0" class="data row1 col0" >go</td>
#                         <td id="T_fb9a8284_a292_11ea_b7a8_351e50286832row1_col1" class="data row1 col1" >569</td>
#             </tr>
#             <tr>
#                         <th id="T_fb9a8284_a292_11ea_b7a8_351e50286832level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_fb9a8284_a292_11ea_b7a8_351e50286832row2_col0" class="data row2 col0" >day</td>
#                         <td id="T_fb9a8284_a292_11ea_b7a8_351e50286832row2_col1" class="data row2 col1" >492</td>
#             </tr>
#             <tr>
#                         <th id="T_fb9a8284_a292_11ea_b7a8_351e50286832level0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_fb9a8284_a292_11ea_b7a8_351e50286832row3_col0" class="data row3 col0" >dont</td>
#                         <td id="T_fb9a8284_a292_11ea_b7a8_351e50286832row3_col1" class="data row3 col1" >482</td>
#             </tr>
#             <tr>
#                         <th id="T_fb9a8284_a292_11ea_b7a8_351e50286832level0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_fb9a8284_a292_11ea_b7a8_351e50286832row4_col0" class="data row4 col0" >going</td>
#                         <td id="T_fb9a8284_a292_11ea_b7a8_351e50286832row4_col1" class="data row4 col1" >472</td>
#             </tr>
#             <tr>
#                         <th id="T_fb9a8284_a292_11ea_b7a8_351e50286832level0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_fb9a8284_a292_11ea_b7a8_351e50286832row5_col0" class="data row5 col0" >work</td>
#                         <td id="T_fb9a8284_a292_11ea_b7a8_351e50286832row5_col1" class="data row5 col1" >467</td>
#             </tr>
#             <tr>
#                         <th id="T_fb9a8284_a292_11ea_b7a8_351e50286832level0_row6" class="row_heading level0 row6" >7</th>
#                         <td id="T_fb9a8284_a292_11ea_b7a8_351e50286832row6_col0" class="data row6 col0" >like</td>
#                         <td id="T_fb9a8284_a292_11ea_b7a8_351e50286832row6_col1" class="data row6 col1" >445</td>
#             </tr>
#             <tr>
#                         <th id="T_fb9a8284_a292_11ea_b7a8_351e50286832level0_row7" class="row_heading level0 row7" >8</th>
#                         <td id="T_fb9a8284_a292_11ea_b7a8_351e50286832row7_col0" class="data row7 col0" >got</td>
#                         <td id="T_fb9a8284_a292_11ea_b7a8_351e50286832row7_col1" class="data row7 col1" >441</td>
#             </tr>
#             <tr>
#                         <th id="T_fb9a8284_a292_11ea_b7a8_351e50286832level0_row8" class="row_heading level0 row8" >9</th>
#                         <td id="T_fb9a8284_a292_11ea_b7a8_351e50286832row8_col0" class="data row8 col0" >today</td>
#                         <td id="T_fb9a8284_a292_11ea_b7a8_351e50286832row8_col1" class="data row8 col1" >427</td>
#             </tr>
#             <tr>
#                         <th id="T_fb9a8284_a292_11ea_b7a8_351e50286832level0_row9" class="row_heading level0 row9" >10</th>
#                         <td id="T_fb9a8284_a292_11ea_b7a8_351e50286832row9_col0" class="data row9 col0" >lol</td>
#                         <td id="T_fb9a8284_a292_11ea_b7a8_351e50286832row9_col1" class="data row9 col1" >427</td>
#             </tr>
#             <tr>
#                         <th id="T_fb9a8284_a292_11ea_b7a8_351e50286832level0_row10" class="row_heading level0 row10" >11</th>
#                         <td id="T_fb9a8284_a292_11ea_b7a8_351e50286832row10_col0" class="data row10 col0" >time</td>
#                         <td id="T_fb9a8284_a292_11ea_b7a8_351e50286832row10_col1" class="data row10 col1" >413</td>
#             </tr>
#             <tr>
#                         <th id="T_fb9a8284_a292_11ea_b7a8_351e50286832level0_row11" class="row_heading level0 row11" >12</th>
#                         <td id="T_fb9a8284_a292_11ea_b7a8_351e50286832row11_col0" class="data row11 col0" >know</td>
#                         <td id="T_fb9a8284_a292_11ea_b7a8_351e50286832row11_col1" class="data row11 col1" >407</td>
#             </tr>
#             <tr>
#                         <th id="T_fb9a8284_a292_11ea_b7a8_351e50286832level0_row12" class="row_heading level0 row12" >13</th>
#                         <td id="T_fb9a8284_a292_11ea_b7a8_351e50286832row12_col0" class="data row12 col0" >back</td>
#                         <td id="T_fb9a8284_a292_11ea_b7a8_351e50286832row12_col1" class="data row12 col1" >402</td>
#             </tr>
#             <tr>
#                         <th id="T_fb9a8284_a292_11ea_b7a8_351e50286832level0_row13" class="row_heading level0 ro

# %%
fig = px.bar(temp_neutral, x="count", y="Common_words", title='Most Commmon Neutral Words', orientation='h', 
             width=700, height=700,color='Common_words')
fig.show()
# Out:
# <div>
#
#
#             <div id="879c7014-bec9-4a8f-a07c-956c012b776e" class="plotly-graph-div" style="height:700px; width:700px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("879c7014-bec9-4a8f-a07c-956c012b776e")) {
#                     Plotly.newPlot(
#                         '879c7014-bec9-4a8f-a07c-956c012b776e',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "get", "marker": {"color": "#636efa"}, "name": "get", "offsetgroup": "get", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [612], "xaxis": "x", "y": ["get"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "go", "marker": {"color": "#EF553B"}, "name": "go", "offsetgroup": "go", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [569], "xaxis": "x", "y": ["go"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "day", "marker": {"color": "#00cc96"}, "name": "day", "offsetgroup": "day", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [492], "xaxis": "x", "y": ["day"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "dont", "marker": {"color": "#ab63fa"}, "name": "dont", "offsetgroup": "dont", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [482], "xaxis": "x", "y": ["dont"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "going", "marker": {"color": "#FFA15A"}, "name": "going", "offsetgroup": "going", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [472], "xaxis": "x", "y": ["going"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "work", "marker": {"color": "#19d3f3"}, "name": "work", "offsetgroup": "work", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [467], "xaxis": "x", "y": ["work"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "like", "marker": {"color": "#FF6692"}, "name": "like", "offsetgroup": "like", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [445], "xaxis": "x", "y": ["like"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "got", "marker": {"color": "#B6E880"}, "name": "got", "offsetgroup": "got", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [441], "xaxis": "x", "y": ["got"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "today", "marker": {"color": "#FF97FF"}, "name": "today", "offsetgroup": "today", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [427], "xaxis": "x", "y": ["today"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "lol", "marker": {"color": "#FECB52"}, "name": "lol", "offsetgroup": "lol", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [427], "xaxis": "x", "y": ["lol"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "time", "marker": {"color": "#636efa"}, "name": "time", "offsetgroup": "time", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [413], "xaxis": "x", "y": ["time"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Common_words=%{y}<br>count=%{x}", "legendgroup": "know", "marker": {"color": "#EF553B"}, "name": "know", "offsetgroup": "know", "orientation": "h", "showlegend":  ...
#                         {"barmode": "relative", "height": 700, "legend": {"title": {"text": "Common_words"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.

# %%
fig = px.treemap(temp_neutral, path=['Common_words'], values='count',title='Tree Of Most Common Neutral Words')
fig.show()
# Out:
# <div>
#
#
#             <div id="d6fc4605-c375-48d9-895f-b6734bcd4b64" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d6fc4605-c375-48d9-895f-b6734bcd4b64")) {
#                     Plotly.newPlot(
#                         'd6fc4605-c375-48d9-895f-b6734bcd4b64',
#                         [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hoverlabel": {"namelength": 0}, "hovertemplate": "labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}", "ids": ["back", "cant", "day", "dont", "get", "go", "going", "got", "home", "know", "like", "lol", "one", "see", "time", "today", "u", "want", "work"], "labels": ["back", "cant", "day", "dont", "get", "go", "going", "got", "home", "know", "like", "lol", "one", "see", "time", "today", "u", "want", "work"], "name": "", "parents": ["", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", ""], "type": "treemap", "values": [402, 339, 492, 482, 612, 569, 472, 441, 335, 407, 445, 427, 394, 349, 413, 427, 376, 319, 467]}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterterna ...

# %% [markdown]
# * We can see words like get,go,dont,got,u,cant,lol,like are common in all three segments . That's interesting because words like dont and cant are more of negative nature and words like lol are more of positive nature.Does this mean our data is incorrectly labelled , we will have more insights on this after N-gram analysis
# * It will be interesting to see the word unique to different sentiments

# %% [markdown]
# ## Let's Look at Unique Words in each Segment
#
# We will look at unique words in each segment in the Following Order:
# * Positive
# * Negative
# * Neutral

# %%
raw_text = [word for word_list in train['temp_list1'] for word in word_list]

# %%
def words_unique(sentiment,numwords,raw_words):
    '''
    Input:
        segment - Segment category (ex. 'Neutral');
        numwords - how many specific words do you want to see in the final result; 
        raw_words - list  for item in train_data[train_data.segments == segments]['temp_list1']:
    Output: 
        dataframe giving information about the name of the specific ingredient and how many times it occurs in the chosen cuisine (in descending order based on their counts)..

    '''
    allother = []
    for item in train[train.sentiment != sentiment]['temp_list1']:
        for word in item:
            allother .append(word)
    allother  = list(set(allother ))
    
    specificnonly = [x for x in raw_text if x not in allother]
    
    mycounter = Counter()
    
    for item in train[train.sentiment == sentiment]['temp_list1']:
        for word in item:
            mycounter[word] += 1
    keep = list(specificnonly)
    
    for word in list(mycounter):
        if word not in keep:
            del mycounter[word]
    
    Unique_words = pd.DataFrame(mycounter.most_common(numwords), columns = ['words','count'])
    
    return Unique_words

# %% [markdown]
# ### Positive Tweets

# %%
Unique_Positive= words_unique('positive', 20, raw_text)
print("The top 20 unique words in Positive Tweets are:")
Unique_Positive.style.background_gradient(cmap='Greens')
# Out:
# The top 20 unique words in Positive Tweets are:
# <style  type="text/css" >
#     #T_282bb39a_a293_11ea_b7a8_351e50286832row0_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_282bb39a_a293_11ea_b7a8_351e50286832row1_col1 {
#             background-color:  #d1edcb;
#             color:  #000000;
#         }    #T_282bb39a_a293_11ea_b7a8_351e50286832row2_col1 {
#             background-color:  #e5f5e0;
#             color:  #000000;
#         }    #T_282bb39a_a293_11ea_b7a8_351e50286832row3_col1 {
#             background-color:  #ebf7e7;
#             color:  #000000;
#         }    #T_282bb39a_a293_11ea_b7a8_351e50286832row4_col1 {
#             background-color:  #ebf7e7;
#             color:  #000000;
#         }    #T_282bb39a_a293_11ea_b7a8_351e50286832row5_col1 {
#             background-color:  #ebf7e7;
#             color:  #000000;
#         }    #T_282bb39a_a293_11ea_b7a8_351e50286832row6_col1 {
#             background-color:  #f1faee;
#             color:  #000000;
#         }    #T_282bb39a_a293_11ea_b7a8_351e50286832row7_col1 {
#             background-color:  #f1faee;
#             color:  #000000;
#         }    #T_282bb39a_a293_11ea_b7a8_351e50286832row8_col1 {
#             background-color:  #f1faee;
#             color:  #000000;
#         }    #T_282bb39a_a293_11ea_b7a8_351e50286832row9_col1 {
#             background-color:  #f1faee;
#             color:  #000000;
#         }    #T_282bb39a_a293_11ea_b7a8_351e50286832row10_col1 {
#             background-color:  #f1faee;
#             color:  #000000;
#         }    #T_282bb39a_a293_11ea_b7a8_351e50286832row11_col1 {
#             background-color:  #f1faee;
#             color:  #000000;
#         }    #T_282bb39a_a293_11ea_b7a8_351e50286832row12_col1 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_282bb39a_a293_11ea_b7a8_351e50286832row13_col1 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_282bb39a_a293_11ea_b7a8_351e50286832row14_col1 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_282bb39a_a293_11ea_b7a8_351e50286832row15_col1 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_282bb39a_a293_11ea_b7a8_351e50286832row16_col1 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_282bb39a_a293_11ea_b7a8_351e50286832row17_col1 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_282bb39a_a293_11ea_b7a8_351e50286832row18_col1 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_282bb39a_a293_11ea_b7a8_351e50286832row19_col1 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }</style><table id="T_282bb39a_a293_11ea_b7a8_351e50286832" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >words</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_282bb39a_a293_11ea_b7a8_351e50286832level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_282bb39a_a293_11ea_b7a8_351e50286832row0_col0" class="data row0 col0" >congratulations</td>
#                         <td id="T_282bb39a_a293_11ea_b7a8_351e50286832row0_col1" class="data row0 col1" >29</td>
#             </tr>
#             <tr>
#                         <th id="T_282bb39a_a293_11ea_b7a8_351e50286832level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_282bb39a_a293_11ea_b7a8_351e50286832row1_col0" class="data row1 col0" >thnx</td>
#                         <td id="T_282bb39a_a293_11ea_b7a8_351e50286832row1_col1" class="data row1 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_282bb39a_a293_11ea_b7a8_351e50286832level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_282bb39a_a293_11ea_b7a8_351e50286832row2_col0" class="data row2 col0" >appreciated</td>
#                         <td id="T_282bb39a_a293_11ea_b7a8_351e50286832row2_col1" class="data row2 col1" >8</td>
#             </tr>
#             <tr>
#                         <th id="T_282bb39a_a293_11ea_b7a8_351e50286832level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_282bb39a_a293_11ea_b7a8_351e50286832row3_col0" class="data row3 col0" >shared</td>
#                         <td id="T_282bb39a_a293_11ea_b7a8_351e50286832row3_col1" class="data row3 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_282bb39a_a293_11ea_b7a8_351e50286832level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_282bb39a_a293_11ea_b7a8_351e50286832row4_col0" class="data row4 col0" >presents</td>
#                         <td id="T_282bb39a_a293_11ea_b7a8_351e50286832row4_col1" class="data row4 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_282bb39a_a293_11ea_b7a8_351e50286832level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_282bb39a_a293_11ea_b7a8_351e50286832row5_col0" class="data row5 col0" >greetings</td>
#                         <td id="T_282bb39a_a293_11ea_b7a8_351e50286832row5_col1" class="data row5 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_282bb39a_a293_11ea_b7a8_351e50286832level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_282bb39a_a293_11ea_b7a8_351e50286832row6_col0" class="data row6 col0" >blessings</td>
#                         <td id="T_282bb39a_a293_11ea_b7a8_351e50286832row6_col1" class="data row6 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_282bb39a_a293_11ea_b7a8_351e50286832level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_282bb39a_a293_11ea_b7a8_351e50286832row7_col0" class="data row7 col0" >mothersday</td>
#                         <td id="T_282bb39a_a293_11ea_b7a8_351e50286832row7_col1" class="data row7 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_282bb39a_a293_11ea_b7a8_351e50286832level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_282bb39a_a293_11ea_b7a8_351e50286832row8_col0" class="data row8 col0" >mcr</td>
#                         <td id="T_282bb39a_a293_11ea_b7a8_351e50286832row8_col1" class="data row8 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_282bb39a_a293_11ea_b7a8_351e50286832level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_282bb39a_a293_11ea_b7a8_351e50286832row9_col0" class="data row9 col0" >coolest</td>
#                         <td id="T_282bb39a_a293_11ea_b7a8_351e50286832row9_col1" class="data row9 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_282bb39a_a293_11ea_b7a8_351e50286832level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_282bb39a_a293_11ea_b7a8_351e50286832row10_col0" class="data row10 col0" >honored</td>
#                         <td id="T_282bb39a_a293_11ea_b7a8_351e50286832row10_col1" class="data row10 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_282bb39a_a293_11ea_b7a8_351e50286832level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_282bb39a_a293_11ea_b7a8_351e50286832row11_col0" class="data row11 col0" >goood</td>
#                         <td id="T_282bb39a_a293_11ea_b7a8_351e50286832row11_col1" class="data row11 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_282bb39a_a293_11ea_b7a8_351e50286832level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_282bb39a_a293_11ea_b7a8_351e50286832row12_col0" class="data row12 col0" >wango</td>
#                         <td id="T_282bb39a_a293_11ea_b7a8_351e50286832row12_col1" class="data row12 col1" >5

# %%
fig = px.treemap(Unique_Positive, path=['words'], values='count',title='Tree Of Unique Positive Words')
fig.show()
# Out:
# <div>
#
#
#             <div id="4227e064-aa14-4af8-96a7-0d9d1d77786c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4227e064-aa14-4af8-96a7-0d9d1d77786c")) {
#                     Plotly.newPlot(
#                         '4227e064-aa14-4af8-96a7-0d9d1d77786c',
#                         [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hoverlabel": {"namelength": 0}, "hovertemplate": "labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}", "ids": ["actress", "appreciated", "blessings", "ciara", "congratulations", "coolest", "dayyyy", "goood", "greetings", "honored", "hurray", "kudos", "mcr", "mint", "mothersday", "presents", "shared", "thnx", "twin", "wango"], "labels": ["actress", "appreciated", "blessings", "ciara", "congratulations", "coolest", "dayyyy", "goood", "greetings", "honored", "hurray", "kudos", "mcr", "mint", "mothersday", "presents", "shared", "thnx", "twin", "wango"], "name": "", "parents": ["", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", ""], "type": "treemap", "values": [5, 8, 6, 5, 29, 6, 5, 6, 7, 6, 5, 5, 6, 5, 6, 7, 7, 10, 5, 5]}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterterna ...

# %%
from palettable.colorbrewer.qualitative import Pastel1_7
plt.figure(figsize=(16,10))
my_circle=plt.Circle((0,0), 0.7, color='white')
plt.pie(Unique_Positive['count'], labels=Unique_Positive.words, colors=Pastel1_7.hex_colors)
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title('DoNut Plot Of Unique Positive Words')
plt.show()

# %%
Unique_Negative= words_unique('negative', 10, raw_text)
print("The top 10 unique words in Negative Tweets are:")
Unique_Negative.style.background_gradient(cmap='Reds')
# Out:
# The top 10 unique words in Negative Tweets are:
# <style  type="text/css" >
#     #T_55175422_a293_11ea_b7a8_351e50286832row0_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_55175422_a293_11ea_b7a8_351e50286832row1_col1 {
#             background-color:  #fb694a;
#             color:  #000000;
#         }    #T_55175422_a293_11ea_b7a8_351e50286832row2_col1 {
#             background-color:  #fdd4c2;
#             color:  #000000;
#         }    #T_55175422_a293_11ea_b7a8_351e50286832row3_col1 {
#             background-color:  #fdd4c2;
#             color:  #000000;
#         }    #T_55175422_a293_11ea_b7a8_351e50286832row4_col1 {
#             background-color:  #fdd4c2;
#             color:  #000000;
#         }    #T_55175422_a293_11ea_b7a8_351e50286832row5_col1 {
#             background-color:  #fdd4c2;
#             color:  #000000;
#         }    #T_55175422_a293_11ea_b7a8_351e50286832row6_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_55175422_a293_11ea_b7a8_351e50286832row7_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_55175422_a293_11ea_b7a8_351e50286832row8_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_55175422_a293_11ea_b7a8_351e50286832row9_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_55175422_a293_11ea_b7a8_351e50286832" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >words</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_55175422_a293_11ea_b7a8_351e50286832level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_55175422_a293_11ea_b7a8_351e50286832row0_col0" class="data row0 col0" >ache</td>
#                         <td id="T_55175422_a293_11ea_b7a8_351e50286832row0_col1" class="data row0 col1" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_55175422_a293_11ea_b7a8_351e50286832level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_55175422_a293_11ea_b7a8_351e50286832row1_col0" class="data row1 col0" >suffering</td>
#                         <td id="T_55175422_a293_11ea_b7a8_351e50286832row1_col1" class="data row1 col1" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_55175422_a293_11ea_b7a8_351e50286832level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_55175422_a293_11ea_b7a8_351e50286832row2_col0" class="data row2 col0" >allergic</td>
#                         <td id="T_55175422_a293_11ea_b7a8_351e50286832row2_col1" class="data row2 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_55175422_a293_11ea_b7a8_351e50286832level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_55175422_a293_11ea_b7a8_351e50286832row3_col0" class="data row3 col0" >cramps</td>
#                         <td id="T_55175422_a293_11ea_b7a8_351e50286832row3_col1" class="data row3 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_55175422_a293_11ea_b7a8_351e50286832level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_55175422_a293_11ea_b7a8_351e50286832row4_col0" class="data row4 col0" >saddest</td>
#                         <td id="T_55175422_a293_11ea_b7a8_351e50286832row4_col1" class="data row4 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_55175422_a293_11ea_b7a8_351e50286832level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_55175422_a293_11ea_b7a8_351e50286832row5_col0" class="data row5 col0" >pissing</td>
#                         <td id="T_55175422_a293_11ea_b7a8_351e50286832row5_col1" class="data row5 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_55175422_a293_11ea_b7a8_351e50286832level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_55175422_a293_11ea_b7a8_351e50286832row6_col0" class="data row6 col0" >sob</td>
#                         <td id="T_55175422_a293_11ea_b7a8_351e50286832row6_col1" class="data row6 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_55175422_a293_11ea_b7a8_351e50286832level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_55175422_a293_11ea_b7a8_351e50286832row7_col0" class="data row7 col0" >dealing</td>
#                         <td id="T_55175422_a293_11ea_b7a8_351e50286832row7_col1" class="data row7 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_55175422_a293_11ea_b7a8_351e50286832level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_55175422_a293_11ea_b7a8_351e50286832row8_col0" class="data row8 col0" >devastated</td>
#                         <td id="T_55175422_a293_11ea_b7a8_351e50286832row8_col1" class="data row8 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_55175422_a293_11ea_b7a8_351e50286832level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_55175422_a293_11ea_b7a8_351e50286832row9_col0" class="data row9 col0" >noes</td>
#                         <td id="T_55175422_a293_11ea_b7a8_351e50286832row9_col1" class="data row9 col1" >6</td>
#             </tr>
#     </tbody></table>

# %%
from palettable.colorbrewer.qualitative import Pastel1_7
plt.figure(figsize=(16,10))
my_circle=plt.Circle((0,0), 0.7, color='white')
plt.rcParams['text.color'] = 'black'
plt.pie(Unique_Negative['count'], labels=Unique_Negative.words, colors=Pastel1_7.hex_colors)
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title('DoNut Plot Of Unique Negative Words')
plt.show()

# %%
Unique_Neutral= words_unique('neutral', 10, raw_text)
print("The top 10 unique words in Neutral Tweets are:")
Unique_Neutral.style.background_gradient(cmap='Oranges')
# Out:
# The top 10 unique words in Neutral Tweets are:
# <style  type="text/css" >
#     #T_80149202_a293_11ea_b7a8_351e50286832row0_col1 {
#             background-color:  #7f2704;
#             color:  #f1f1f1;
#         }    #T_80149202_a293_11ea_b7a8_351e50286832row1_col1 {
#             background-color:  #fd8c3b;
#             color:  #000000;
#         }    #T_80149202_a293_11ea_b7a8_351e50286832row2_col1 {
#             background-color:  #fdd0a2;
#             color:  #000000;
#         }    #T_80149202_a293_11ea_b7a8_351e50286832row3_col1 {
#             background-color:  #fdd0a2;
#             color:  #000000;
#         }    #T_80149202_a293_11ea_b7a8_351e50286832row4_col1 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_80149202_a293_11ea_b7a8_351e50286832row5_col1 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_80149202_a293_11ea_b7a8_351e50286832row6_col1 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_80149202_a293_11ea_b7a8_351e50286832row7_col1 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_80149202_a293_11ea_b7a8_351e50286832row8_col1 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_80149202_a293_11ea_b7a8_351e50286832row9_col1 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }</style><table id="T_80149202_a293_11ea_b7a8_351e50286832" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >words</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_80149202_a293_11ea_b7a8_351e50286832level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_80149202_a293_11ea_b7a8_351e50286832row0_col0" class="data row0 col0" >settings</td>
#                         <td id="T_80149202_a293_11ea_b7a8_351e50286832row0_col1" class="data row0 col1" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_80149202_a293_11ea_b7a8_351e50286832level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_80149202_a293_11ea_b7a8_351e50286832row1_col0" class="data row1 col0" >explain</td>
#                         <td id="T_80149202_a293_11ea_b7a8_351e50286832row1_col1" class="data row1 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_80149202_a293_11ea_b7a8_351e50286832level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_80149202_a293_11ea_b7a8_351e50286832row2_col0" class="data row2 col0" >mite</td>
#                         <td id="T_80149202_a293_11ea_b7a8_351e50286832row2_col1" class="data row2 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_80149202_a293_11ea_b7a8_351e50286832level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_80149202_a293_11ea_b7a8_351e50286832row3_col0" class="data row3 col0" >hiya</td>
#                         <td id="T_80149202_a293_11ea_b7a8_351e50286832row3_col1" class="data row3 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_80149202_a293_11ea_b7a8_351e50286832level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_80149202_a293_11ea_b7a8_351e50286832row4_col0" class="data row4 col0" >reader</td>
#                         <td id="T_80149202_a293_11ea_b7a8_351e50286832row4_col1" class="data row4 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_80149202_a293_11ea_b7a8_351e50286832level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_80149202_a293_11ea_b7a8_351e50286832row5_col0" class="data row5 col0" >pr</td>
#                         <td id="T_80149202_a293_11ea_b7a8_351e50286832row5_col1" class="data row5 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_80149202_a293_11ea_b7a8_351e50286832level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_80149202_a293_11ea_b7a8_351e50286832row6_col0" class="data row6 col0" >sorta</td>
#                         <td id="T_80149202_a293_11ea_b7a8_351e50286832row6_col1" class="data row6 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_80149202_a293_11ea_b7a8_351e50286832level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_80149202_a293_11ea_b7a8_351e50286832row7_col0" class="data row7 col0" >fathers</td>
#                         <td id="T_80149202_a293_11ea_b7a8_351e50286832row7_col1" class="data row7 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_80149202_a293_11ea_b7a8_351e50286832level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_80149202_a293_11ea_b7a8_351e50286832row8_col0" class="data row8 col0" >enterprise</td>
#                         <td id="T_80149202_a293_11ea_b7a8_351e50286832row8_col1" class="data row8 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_80149202_a293_11ea_b7a8_351e50286832level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_80149202_a293_11ea_b7a8_351e50286832row9_col0" class="data row9 col0" >guessed</td>
#                         <td id="T_80149202_a293_11ea_b7a8_351e50286832row9_col1" class="data row9 col1" >5</td>
#             </tr>
#     </tbody></table>

# %%
from palettable.colorbrewer.qualitative import Pastel1_7
plt.figure(figsize=(16,10))
my_circle=plt.Circle((0,0), 0.7, color='white')
plt.pie(Unique_Neutral['count'], labels=Unique_Neutral.words, colors=Pastel1_7.hex_colors)
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title('DoNut Plot Of Unique Neutral Words')
plt.show()

# %% [markdown]
# **By Looking at the Unique Words of each sentiment,we now have much more clarity about the data,these unique words are very strong determiners of Sentiment of tweets**

# %% [markdown]
# ## It's Time For WordClouds
#
# We will be building wordclouds in the following order:
#
# * WordCloud of Neutral Tweets
# * WordCloud of Positive Tweets
# * WordCloud of Negative Tweets

# %%
def plot_wordcloud(text, mask=None, max_words=200, max_font_size=100, figure_size=(24.0,16.0), color = 'white',
                   title = None, title_size=40, image_color=False):
    stopwords = set(STOPWORDS)
    more_stopwords = {'u', "im"}
    stopwords = stopwords.union(more_stopwords)

    wordcloud = WordCloud(background_color=color,
                    stopwords = stopwords,
                    max_words = max_words,
                    max_font_size = max_font_size, 
                    random_state = 42,
                    width=400, 
                    height=200,
                    mask = mask)
    wordcloud.generate(str(text))
    
    plt.figure(figsize=figure_size)
    if image_color:
        image_colors = ImageColorGenerator(mask);
        plt.imshow(wordcloud.recolor(color_func=image_colors), interpolation="bilinear");
        plt.title(title, fontdict={'size': title_size,  
                                  'verticalalignment': 'bottom'})
    else:
        plt.imshow(wordcloud);
        plt.title(title, fontdict={'size': title_size, 'color': 'black', 
                                  'verticalalignment': 'bottom'})
    plt.axis('off');
    plt.tight_layout()  
d = '/kaggle/input/masks-for-wordclouds/'

# %% [markdown]
# I have added more words like im , u (that we say were there in the most common words,disturbing our analysis) as stopwords

# %% [markdown]
# #### WORDCLOUD OF NEUTRAL TWEETS
#
# We Have already visualized our Most Common Negative words ,but Wordclouds Provide us much more clarity

# %%
#pos_mask = np.array(Image.open(d+ 'twitter_mask.png'))
plot_wordcloud(Neutral_sent.text,color='white',max_font_size=100,title_size=30,title="WordCloud of Neutral Tweets")

# %%
plot_wordcloud(Positive_sent.text,title="Word Cloud Of Positive tweets",title_size=30)

# %%
plot_wordcloud(Negative_sent.text,title="Word Cloud of Negative Tweets",color='white',title_size=30)

# %% [markdown]
# Modelling

# %%
df_train = pd.read_csv('/kaggle/input/tweet-sentiment-extraction/train.csv')
df_test = pd.read_csv('/kaggle/input/tweet-sentiment-extraction/test.csv')
df_submission = pd.read_csv('/kaggle/input/tweet-sentiment-extraction/sample_submission.csv')

# %%
df_train['Num_words_text'] = df_train['text'].apply(lambda x:len(str(x).split())) #Number Of words in main Text in train set

# %%
df_train = df_train[df_train['Num_words_text']>=3]

# %% [markdown]
# **For Full Understanding of the how to train spacy NER with custom inputs, please read the spacy documentation along with the code presentation in this notebook : https://spacy.io/usage/training#ner Follow along from Updating Spacy NER**

# %%
def save_model(output_dir, nlp, new_model_name):
    ''' This Function Saves model to 
    given output directory'''
    
    output_dir = f'../working/{output_dir}'
    if output_dir is not None:        
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
        nlp.meta["name"] = new_model_name
        nlp.to_disk(output_dir)
        print("Saved model to", output_dir)

# %%
# pass model = nlp if you want to train on top of existing model 

def train(train_data, output_dir, n_iter=20, model=None):
    """Load the model, set up the pipeline and train the entity recognizer."""
    ""
    if model is not None:
        nlp = spacy.load(output_dir)  # load existing spaCy model
        print("Loaded model '%s'" % model)
    else:
        nlp = spacy.blank("en")  # create blank Language class
        print("Created blank 'en' model")
    
    # create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
    if "ner" not in nlp.pipe_names:
        ner = nlp.create_pipe("ner")
        nlp.add_pipe(ner, last=True)
    # otherwise, get it so we can add labels
    else:
        ner = nlp.get_pipe("ner")
    
    # add labels
    for _, annotations in train_data:
        for ent in annotations.get("entities"):
            ner.add_label(ent[2])

    # get names of other pipes to disable them during training
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != "ner"]
    with nlp.disable_pipes(*other_pipes):  # only train NER
        # sizes = compounding(1.0, 4.0, 1.001)
        # batch up the examples using spaCy's minibatch
        if model is None:
            nlp.begin_training()
        else:
            nlp.resume_training()


        for itn in tqdm(range(n_iter)):
            random.shuffle(train_data)
            batches = minibatch(train_data, size=compounding(4.0, 500.0, 1.001))    
            losses = {}
            for batch in batches:
                texts, annotations = zip(*batch)
                nlp.update(texts,  # batch of texts
                            annotations,  # batch of annotations
                            drop=0.5,   # dropout - make it harder to memorise data
                            losses=losses, 
                            )
            print("Losses", losses)
    save_model(output_dir, nlp, 'st_ner')

# %%
def get_model_out_path(sentiment):
    '''
    Returns Model output path
    '''
    model_out_path = None
    if sentiment == 'positive':
        model_out_path = 'models/model_pos'
    elif sentiment == 'negative':
        model_out_path = 'models/model_neg'
    return model_out_path

# %%
def get_training_data(sentiment):
    '''
    Returns Trainong data in the format needed to train spacy NER
    '''
    train_data = []
    for index, row in df_train.iterrows():
        if row.sentiment == sentiment:
            selected_text = row.selected_text
            text = row.text
            start = text.find(selected_text)
            end = start + len(selected_text)
            train_data.append((text, {"entities": [[start, end, 'selected_text']]}))
    return train_data

# %% [markdown]
# #### Training models for Positive and Negative tweets

# %%
sentiment = 'positive'

train_data = get_training_data(sentiment)
model_path = get_model_out_path(sentiment)
# For DEmo Purposes I have taken 3 iterations you can train the model as you want
train(train_data, model_path, n_iter=3, model=None)
# Out:
# Created blank 'en' model
#  33%|███▎      | 1/3 [00:51<01:43, 51.93s/it]
# Losses {'ner': 33874.54902399445}
#  67%|██████▋   | 2/3 [01:43<00:51, 51.70s/it]
# Losses {'ner': 30788.22600837807}
# 100%|██████████| 3/3 [02:33<00:00, 51.31s/it]
# Losses {'ner': 29425.017946831635}
# Saved model to ../working/models/model_pos

# %%
sentiment = 'negative'

train_data = get_training_data(sentiment)
model_path = get_model_out_path(sentiment)

train(train_data, model_path, n_iter=3, model=None)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Created blank 'en' model
#  33%|███▎      | 1/3 [00:48<01:37, 48.89s/it]
# Losses {'ner': 32020.51984877314}
#  67%|██████▋   | 2/3 [01:37<00:48, 48.67s/it]
# Losses {'ner': 28707.59838432999}
# 100%|██████████| 3/3 [02:24<00:00, 48.31s/it]
# Losses {'ner': 27115.79590147591}
# Saved model to ../working/models/model_neg

# %% [markdown]
# ### Predicting with the trained Model

# %%
def predict_entities(text, model):
    doc = model(text)
    ent_array = []
    for ent in doc.ents:
        start = text.find(ent.text)
        end = start + len(ent.text)
        new_int = [start, end, ent.label_]
        if new_int not in ent_array:
            ent_array.append([start, end, ent.label_])
    selected_text = text[ent_array[0][0]: ent_array[0][1]] if len(ent_array) > 0 else text
    return selected_text

# %%
selected_texts = []
MODELS_BASE_PATH = '../input/tse-spacy-model/models/'

if MODELS_BASE_PATH is not None:
    print("Loading Models  from ", MODELS_BASE_PATH)
    model_pos = spacy.load(MODELS_BASE_PATH + 'model_pos')
    model_neg = spacy.load(MODELS_BASE_PATH + 'model_neg')
        
    for index, row in df_test.iterrows():
        text = row.text
        output_str = ""
        if row.sentiment == 'neutral' or len(text.split()) <= 2:
            selected_texts.append(text)
        elif row.sentiment == 'positive':
            selected_texts.append(predict_entities(text, model_pos))
        else:
            selected_texts.append(predict_entities(text, model_neg))
        
df_test['selected_text'] = selected_texts
# Out:
# Loading Models  from  ../input/tse-spacy-model/models/

# %%
df_submission['selected_text'] = df_test['selected_text']
df_submission.to_csv("submission.csv", index=False)
display(df_submission.head(10))
# Out:
#        textID                                      selected_text
# 0  f87dea47db  Last session of the day  http://twitpic.com/67ezh
# 1  96d74cb729                                           exciting
# 2  eee518ae67                                          Recession
# 3  01082688c6                                        happy bday!
# 4  33987a8ee5                                        I like it!!
# 5  726e501993                                          visitors!
# 6  261932614e                                              HATES
# 7  afa11da83f                                            blocked
# 8  e64208b4ef   and within a short time of the last clue all ...
# 9  37bcad24ca   What did you get?  My day is alright.. haven`...
